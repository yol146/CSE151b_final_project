# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, os.path, errno
import pickle
from glob import glob
import numpy as np
import random
import sys
from tqdm import trange
import matplotlib.pyplot as plt
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
# Get the device
if (torch.cuda.is_available()):
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu")



"""
    number of trajectories in each city
    # austin --  train: 43041 test: 6325 
    # miami -- train: 55029 test:7971
    # pittsburgh -- train: 43544 test: 6361
    # dearborn -- train: 24465 test: 3671
    # washington-dc -- train: 25744 test: 3829
    # palo-alto -- train:  11993 test:1686

    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds
    
"""
# Out:
# '\n    number of trajectories in each city\n    # austin --  train: 43041 test: 6325 \n    # miami -- train: 55029 test:7971\n    # pittsburgh -- train: 43544 test: 6361\n    # dearborn -- train: 24465 test: 3671\n    # washington-dc -- train: 25744 test: 3829\n    # palo-alto -- train:  11993 test:1686\n\n    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds\n    \n'

# %% [markdown]
# # Data Processing

# %%
from glob import glob
import pickle
import numpy as np

ROOT_PATH = "./argo2/"

cities = ["austin", "miami", "pittsburgh", "dearborn", "washington-dc", "palo-alto"]
splits = ["train", "test"]

# # intialize a dataset
city = 'austin' 
split = 'train'

def get_city_trajectories(city="palo-alto", split="train", normalized=False):
    
    outputs = None
    
    if split=="train":
        f_in = ROOT_PATH + split + "/" + city + "_inputs"
        inputs = pickle.load(open(f_in, "rb"))
        n = len(inputs)
        inputs = np.asarray(inputs)[:int(n * 0.2)]
        
        f_out = ROOT_PATH + split + "/" + city + "_outputs"
        outputs = pickle.load(open(f_out, "rb"))
        outputs = np.asarray(outputs)[:int(n * 0.2)]
        
    elif split == 'val':
        f_in = ROOT_PATH + 'train' + "/" + city + "_inputs"
        inputs = pickle.load(open(f_in, "rb"))
        n = len(inputs)
        inputs = np.asarray(inputs)[int(n * 0.2):]
        
        f_out = ROOT_PATH + 'train' + "/" + city + "_outputs"
        outputs = pickle.load(open(f_out, "rb"))
        outputs = np.asarray(outputs)[int(n * 0.2):]
    
    else:
        f_in = ROOT_PATH + split + "/" + city + "_inputs"
        inputs = pickle.load(open(f_in, "rb"))
        n = len(inputs)
        inputs = np.asarray(inputs)

    return inputs, outputs

class ArgoverseDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, city: str, split:str, transform=None):
        super(ArgoverseDataset, self).__init__()
        self.transform = transform

        self.inputs, self.outputs = get_city_trajectories(city=city, split=split, normalized=False)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        
#         tensor = torch.Tensor(self.feature[item])
#         tensorlabel = torch.Tensor(self.label[item])
#         return tensor.to(device), tensorlabel.to(device)

        data = np.concatenate((self.inputs[idx], self.outputs[idx]))
            
        if self.transform:
            data = self.transform(data)

        return torch.Tensor(data).to(device)

# %% [markdown]
# # Seq2Seq LSTM Model Implementation

# %%
# Credit: Laura Kulowski


class lstm_encoder(nn.Module):
    ''' Encodes time-series sequence '''

    def __init__(self, input_size, hidden_size, num_layers = 1):
        
        '''
        : param input_size:     the number of features in the input X
        : param hidden_size:    the number of features in the hidden state h
        : param num_layers:     number of recurrent layers (i.e., 2 means there are
        :                       2 stacked LSTMs)
        '''
        
        super(lstm_encoder, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout = nn.Dropout(0.6)

        # define LSTM layer
        self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size,
                            num_layers = num_layers)

    def forward(self, x_input):
        
        '''
        : param x_input:               input of shape (seq_len, # in batch, input_size)
        : return lstm_out, hidden:     lstm_out gives all the hidden states in the sequence;
        :                              hidden gives the hidden state and cell state for the last
        :                              element in the sequence 
        '''
        
        x_input = self.dropout(x_input)
        lstm_out, self.hidden = self.lstm(x_input.view(x_input.shape[0], x_input.shape[1], self.input_size))
        
        return lstm_out, self.hidden     
    
    def init_hidden(self, batch_size):
        
        '''
        initialize hidden state
        : param batch_size:    x_input.shape[1]
        : return:              zeroed hidden state and cell state 
        '''
        
        return (torch.zeros(self.num_layers, batch_size, self.hidden_size),
                torch.zeros(self.num_layers, batch_size, self.hidden_size))


class lstm_decoder(nn.Module):
    ''' Decodes hidden state output by encoder '''
    
    def __init__(self, input_size, hidden_size, num_layers = 1):

        '''
        : param input_size:     the number of features in the input X
        : param hidden_size:    the number of features in the hidden state h
        : param num_layers:     number of recurrent layers (i.e., 2 means there are
        :                       2 stacked LSTMs)
        '''
        
        super(lstm_decoder, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout = nn.Dropout(0.6)

        self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_size,
                            num_layers = num_layers)
        self.linear = nn.Linear(hidden_size, input_size)           

    def forward(self, x_input, encoder_hidden_states):
        
        '''        
        : param x_input:                    should be 2D (batch_size, input_size)
        : param encoder_hidden_states:      hidden states
        : return output, hidden:            output gives all the hidden states in the sequence;
        :                                   hidden gives the hidden state and cell state for the last
        :                                   element in the sequence 
 
        '''
        
        x_input = self.dropout(x_input)
        lstm_out, self.hidden = self.lstm(x_input.unsqueeze(0), encoder_hidden_states)
        output = self.linear(lstm_out.squeeze(0))     
        
        return output, self.hidden

class lstm_seq2seq(nn.Module):
    ''' train LSTM encoder-decoder and make predictions '''
    
    def __init__(self, input_size, hidden_size):

        '''
        : param input_size:     the number of expected features in the input X
        : param hidden_size:    the number of features in the hidden state h
        '''

        super(lstm_seq2seq, self).__init__()

        self.input_size = input_size
        self.hidden_size = hidden_size

        self.encoder = lstm_encoder(input_size = input_size, hidden_size = hidden_size)
        self.decoder = lstm_decoder(input_size = input_size, hidden_size = hidden_size)


    def train_model(self, input_tensor, target_tensor, n_epochs, target_len, batch_size, training_prediction = 'recursive', teacher_forcing_ratio = 0.5, learning_rate = 0.01, dynamic_tf = False):
        
        '''
        train lstm encoder-decoder
        
        : param input_tensor:              input data with shape (seq_len, # in batch, number features); PyTorch tensor    
        : param target_tensor:             target data with shape (seq_len, # in batch, number features); PyTorch tensor
        : param n_epochs:                  number of epochs 
        : param target_len:                number of values to predict 
        : param batch_size:                number of samples per gradient update
        : param training_prediction:       type of prediction to make during training ('recursive', 'teacher_forcing', or
        :                                  'mixed_teacher_forcing'); default is 'recursive'
        : param teacher_forcing_ratio:     float [0, 1) indicating how much teacher forcing to use when
        :                                  training_prediction = 'teacher_forcing.' For each batch in training, we generate a random
        :                                  number. If the random number is less than teacher_forcing_ratio, we use teacher forcing.
        :                                  Otherwise, we predict recursively. If teacher_forcing_ratio = 1, we train only using
        :                                  teacher forcing.
        : param learning_rate:             float >= 0; learning rate
        : param dynamic_tf:                use dynamic teacher forcing (True/False); dynamic teacher forcing
        :                                  reduces the amount of teacher forcing for each epoch
        : return losses:                   array of loss function for each epoch
        '''
        
        # initialize array of losses 
        losses = np.full(n_epochs, np.nan)

        optimizer = optim.Adam(self.parameters(), lr = learning_rate)
        criterion = nn.MSELoss()

        # calculate number of batch iterations
        n_batches = int(input_tensor.shape[1] / batch_size)

        with trange(n_epochs) as tr:
            for it in tr:
                
                batch_loss = 0.
                batch_loss_tf = 0.
                batch_loss_no_tf = 0.
                num_tf = 0
                num_no_tf = 0

                for b in range(n_batches):
#                     print("at batch: ", b, "/", n_batches)
                    # select data 
                    input_batch = input_tensor[:, b: b + batch_size, :]
                    target_batch = target_tensor[:, b: b + batch_size, :]

                    # outputs tensor
                    outputs = torch.zeros(target_len, batch_size, input_batch.shape[2]).to(device)

                    # initialize hidden state
                    encoder_hidden = self.encoder.init_hidden(batch_size)

                    # zero the gradient
                    optimizer.zero_grad()

                    # encoder outputs
                    encoder_output, encoder_hidden = self.encoder(input_batch)

                    # decoder with teacher forcing
                    decoder_input = input_batch[-1, :, :]   # shape: (batch_size, input_size)
                    decoder_hidden = encoder_hidden

                    if training_prediction == 'recursive':
                        # predict recursively
                        for t in range(target_len): 
                            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
                            outputs[t] = decoder_output
                            decoder_input = decoder_output

                    if training_prediction == 'teacher_forcing':
                        # use teacher forcing
                        if random.random() < teacher_forcing_ratio:
                            for t in range(target_len): 
                                decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
                                outputs[t] = decoder_output
                                decoder_input = target_batch[t, :, :]

                        # predict recursively 
                        else:
                            for t in range(target_len): 
                                decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
                                outputs[t] = decoder_output
                                decoder_input = decoder_output

                    if training_prediction == 'mixed_teacher_forcing':
                        # predict using mixed teacher forcing
                        for t in range(target_len):
                            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
                            outputs[t] = decoder_output
                            
                            # predict with teacher forcing
                            if random.random() < teacher_forcing_ratio:
                                decoder_input = target_batch[t, :, :]
                            
                            # predict recursively 
                            else:
                                decoder_input = decoder_output

                    # compute the loss 
                    loss = criterion(outputs, target_batch)
                    batch_loss += loss.item()
                    
                    # backpropagation
                    loss.backward()
                    optimizer.step()

                # loss for epoch 
                batch_loss /= n_batches 
                losses[it] = batch_loss

                # dynamic teacher forcing
                if dynamic_tf and teacher_forcing_ratio > 0:
                    teacher_forcing_ratio = teacher_forcing_ratio - 0.02 

                # progress bar 
                tr.set_postfix(loss="{0:.3f}".format(batch_loss))
                    
        return losses

    def predict(self, input_tensor, target_len):
        
        '''
        : param input_tensor:      input data (seq_len, input_size); PyTorch tensor 
        : param target_len:        number of target values to predict 
        : return np_outputs:       np.array containing predicted values; prediction done recursively 
        '''

        # encode input_tensor
        input_tensor = input_tensor.unsqueeze(1)     # add in batch size of 1
        encoder_output, encoder_hidden = self.encoder(input_tensor)

        # initialize tensor for predictions
        outputs = torch.zeros(target_len, input_tensor.shape[2])

        # decode input_tensor
        decoder_input = input_tensor[-1, :, :]
        decoder_hidden = encoder_hidden
        
        for t in range(target_len):
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            outputs[t] = decoder_output.squeeze(0)
            decoder_input = decoder_output
            
        np_outputs = outputs.detach().numpy()
        
        return np_outputs

# %%
#     takes in the original data array
#     returns the velocity array as (inputVel(x,y), outputVel(x,y)), starting from the 2nd step
def calcVelocity(dataArr):
    dataWV = []
    for path in np.array(dataArr):
        pathWV = []
#         get rid of the initial velocity
#         pathWV.append(path[1] - path[0])
        for coord in range(1, len(path)):
            changePos = path[coord] - path[coord-1]
#             Code for only velocity
            vel = path[coord] - path[coord-1]
            pathWV.append(vel)

#             Position change with actual velocity
#             posWithVel = np.concatenate((changePos, changePos*10))
#             pathWV.append(posWithVel)
    
        dataWV.append(pathWV)
    inp = []
    oup = []
    for path in dataWV:
        inp.append(path[:49])
        oup.append(path[49:])
    return np.array(inp), np.array(oup)

def getVelData(city, split):
    # get train data
    inp, oup = get_city_trajectories(city=city, split=split, normalized=False)
    # get whole path to calculate velocity
    togetherArr = []
    for i in range(len(inp)):
        togetherData = np.concatenate((inp[i], oup[i]))
        togetherArr.append(togetherData)
    inp, oup = calcVelocity(togetherArr)
    return inp, oup

# %%
city = 'austin' 
split = 'train'


inputs, outputs = getVelData(city, split)
inpVal, oupVal = getVelData(city, 'val')
    
in_tensor = torch.swapaxes(torch.Tensor(inputs),0,1).to(device)
out_tensor = torch.swapaxes(torch.Tensor(outputs),0,1).to(device)

# %%
print(out_tensor.shape)
# Out:
# torch.Size([60, 6456, 2])

# %%
# define hyper parameters
learning_rate = 0.0005
epochs = 1200
input_dim = 2
hidden_dim = 512
layer_count = 1
output_dim = 2
batch_size = 256

target_len = 60
training_prediction = 'mixed_teacher_forcing'
teacher_forcing_ratio = 0.5

# specify model parameters and train
model = lstm_seq2seq(input_size = input_dim, hidden_size = hidden_dim).to(device)

# %%
# current Training is with DropOut = 0.6
for cityT in cities:
    trainNSave(cityT, learning_rate, epochs, input_dim, hidden_dim, layer_count, output_dim, batch_size, target_len, training_prediction=training_prediction, teacher_forcing_ratio=teacher_forcing_ratio)
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 1200/1200 [51:48<00:00,  2.59s/it, loss=0.001]
# 100%|████████████████████████████████████████████████████████████████| 1200/1200 [1:05:51<00:00,  3.29s/it, loss=0.000]
# 100%|██████████████████████████████████████████████████████████████████| 1200/1200 [53:21<00:00,  2.67s/it, loss=0.000]
# 100%|██████████████████████████████████████████████████████████████████| 1200/1200 [29:49<00:00,  1.49s/it, loss=0.001]
# 100%|██████████████████████████████████████████████████████████████████| 1200/1200 [31:28<00:00,  1.57s/it, loss=0.001]
# 100%|██████████████████████████████████████████████████████████████████| 1200/1200 [14:10<00:00,  1.41it/s, loss=0.003]

# %%
# loss = model.train_model(in_tensor, out_tensor, n_epochs = epochs, target_len = target_len, batch_size = batch_size, training_prediction = training_prediction, teacher_forcing_ratio = teacher_forcing_ratio, learning_rate = learning_rate, dynamic_tf = False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 1200/1200 [11:47<00:00,  1.70it/s, loss=0.001]

# %%
totalacc, mseArr = validate(model, 'austin')
# Out:
# validating,  0 / 34433
# validating,  1 / 34433
# validating,  2 / 34433
# validating,  3 / 34433
# validating,  4 / 34433
# validating,  5 / 34433
# validating,  6 / 34433
# validating,  7 / 34433
# validating,  8 / 34433
# validating,  9 / 34433
# validating,  10 / 34433
# validating,  11 / 34433
# validating,  12 / 34433
# validating,  13 / 34433
# validating,  14 / 34433
# validating,  15 / 34433
# validating,  16 / 34433
# validating,  17 / 34433
# validating,  18 / 34433
# validating,  19 / 34433
# validating,  20 / 34433
# validating,  21 / 34433
# validating,  22 / 34433
# validating,  23 / 34433
# validating,  24 / 34433
# validating,  25 / 34433
# validating,  26 / 34433
# validating,  27 / 34433
# validating,  28 / 34433
# validating,  29 / 34433
# validating,  30 / 34433
# validating,  31 / 34433
# validating,  32 / 34433
# validating,  33 / 34433
# validating,  34 / 34433
# validating,  35 / 34433
# validating,  36 / 34433
# validating,  37 / 34433
# validating,  38 / 34433
# validating,  39 / 34433
# validating,  40 / 34433
# validating,  41 / 34433
# validating,  42 / 34433
# validating,  43 / 34433
# validating,  44 / 34433
# validating,  45 / 34433
# validating,  46 / 34433
# validating,  47 / 34433
# validating,  48 / 34433
# validating,  49 / 34433
# validating,  50 / 34433
# validating,  51 / 34433
# validating,  52 / 34433
# validating,  53 / 34433
# validating,  54 / 34433
# validating,  55 / 34433
# validating,  56 / 34433
# validating,  57 / 34433
# validating,  58 / 34433
# validating,  59 / 34433
# validating,  60 / 34433
# validating,  61 / 34433
# validating,  62 / 34433
# validating,  63 / 34433
# validating,  64 / 34433
# validating,  65 / 34433
# validating,  66 / 34433
# validating,  67 / 34433
# validating,  68 / 34433
# validating,  69 / 34433
# validating,  70 / 34433
# validating,  71 / 34433
# validating,  72 / 34433
# validating,  73 / 34433
# validating,  74 / 34433
# validating,  75 / 34433
# validating,  76 / 34433
# validating,  77 / 34433
# validating,  78 / 34433
# validating,  79 / 34433
# validating,  80 / 34433
# validating,  81 / 34433
# validating,  82 / 34433
# validating,  83 / 34433
# validating,  84 / 34433
# validating,  85 / 34433
# validating,  86 / 34433
# validating,  87 / 34433
# validating,  88 / 34433
# validating,  89 / 34433
# validating,  90 / 34433
# validating,  91 / 34433
# validating,  92 / 34433
# validating,  93 / 34433
# validating,  94 / 34433
# validating,  95 / 34433
# validating,  96 / 34433
# validating,  97 / 34433
# validating,  98 / 34433
# validating,  99 / 34433
# validating,  100 / 34433
# validating,  101 / 34433
# validating,  102 / 34433
# validating,  103 / 34433
# validating,  104 / 34433
# validating,  105 / 34433
# validating,  106 / 34433
# validating,  107 / 34433
# validating,  108 / 34433
# validating,  109 / 34433
# validating,  110 / 34433
# validating,  111 / 34433
# validating,  112 / 34433
# validating,  113 / 34433
# validating,  114 / 34433
# validating,  115 / 34433
# validating,  116 / 34433
# validating,  117 / 34433
# validating,  118 / 34433
# validating,  119 / 34433
# validating,  120 / 34433
# validating,  121 / 34433
# validating,  122 / 34433
# validating,  123 / 34433
# validating,  124 / 34433
# validating,  125 / 34433
# validating,  126 / 34433
# validating,  127 / 34433
# validating,  128 / 34433
# validating,  129 / 34433
# validating,  130 / 34433
# validating,  131 / 34433
# validating,  132 / 34433
# validating,  133 / 34433
# validating,  134 / 34433
# validating,  135 / 34433
# validating,  136 / 34433
# validating,  137 / 34433
# validating,  138 / 34433
# validating,  139 / 34433
# validating,  140 / 34433
# validating,  141 / 34433
# validating,  142 / 34433
# validating,  143 / 34433
# validating,  144 / 34433
# validating,  145 / 34433
# validating,  146 / 34433
# validating,  147 / 34433
# validating,  148 / 34433
# validating,  149 / 34433
# validating,  150 / 34433
# validating,  151 / 34433
# validating,  152 / 34433
# validating,  153 / 34433
# validating,  154 / 34433
# validating,  155 / 34433
# validating,  156 / 34433
# validating,  157 / 34433
# validating,  158 / 34433
# validating,  159 / 34433
# validating,  160 / 34433
# validating,  161 / 34433
# validating,  162 / 34433
# validating,  163 / 34433
# validating,  164 / 34433
# validating,  165 / 34433
# validating,  166 / 34433
# validating,  167 / 34433
# validating,  168 / 34433
# validating,  169 / 34433
# validating,  170 / 34433
# validating,  171 / 34433
# validating,  172 / 34433
# validating,  173 / 34433
# validating,  174 / 34433
# validating,  175 / 34433
# validating,  176 / 34433
# validating,  177 / 34433
# validating,  178 / 34433
# validating,  179 / 34433
# validating,  180 / 34433
# validating,  181 / 34433
# validating,  182 / 34433
# validating,  183 / 34433
# validating,  184 / 34433
# validating,  185 / 34433
# validating,  186 / 34433
# validating,  187 / 34433
# validating,  188 / 34433
# validating,  189 / 34433
# validating,  190 / 34433
# validating,  191 / 34433
# validating,  192 / 34433
# validating,  193 / 34433
# validating,  194 / 34433
# validating,  195 / 34433
# validating,  196 / 34433
# validating,  197 / 34433
# validating,  198 / 34433
# validating,  199 / 34433
# validating,  200 / 34433
# validating,  201 / 34433
# validating,  202 / 34433
# validating,  203 / 34433
# validating,  204 / 34433
# validating,  205 / 34433
# validating,  206 / 34433
# validating,  207 / 34433
# validating,  208 / 34433
# validating,  209 / 34433
# validating,  210 / 34433
# validating,  211 / 34433
# validating,  212 / 34433
# validating,  213 / 34433
# validating,  214 / 34433
# validating,  215 / 34433
# validating,  216 / 34433
# validating,  217 / 34433
# validating,  218 / 34433
# validating,  219 / 34433
# validating,  220 / 34433
# validating,  221 / 34433
# validating,  222 / 34433
# validating,  223 / 34433
# validating,  224 / 34433
# validating,  225 / 34433
# validating,  226 / 34433
# validating,  227 / 34433
# validating,  228 / 34433
# validating,  229 / 34433
# validating,  230 / 34433
# validating,  231 / 34433
# validating,  232 / 34433
# validating,  233 / 34433
# validating,  234 / 34433
# validating,  235 / 34433
# validating,  236 / 34433
# validating,  237 / 34433
# validating,  238 / 34433
# validating,  239 / 34433
# validating,  240 / 34433
# validating,  241 / 34433
# validating,  242 / 34433
# validating,  243 / 34433
# validating,  244 / 34433
# validating,  245 / 34433
# validating,  246 / 34433
# validating,  247 / 34433
# validating,  248 / 34433
# validating,  249 / 34433
# validating,  250 / 34433
# validating,  251 / 34433
# validating,  252 / 34433
# validating,  253 / 34433
# validating,  254 / 34433
# validating,  255 / 34433
# validating,  256 / 34433
# validating,  257 / 34433
# validating,  258 / 34433
# validating,  259 / 34433
# validating,  260 / 34433
# validating,  261 / 34433
# validating,  262 / 34433
# validating,  263 / 34433
# validating,  264 / 34433
# validating,  265 / 34433
# validating,  266 / 34433
# validating,  267 / 34433
# validating,  268 / 34433
# validating,  269 / 34433
# validating,  270 / 34433
# validating,  271 / 34433
# validating,  272 / 34433
# validating,  273 / 34433
# validating,  274 / 34433
# validating,  275 / 34433
# validating,  276 / 34433
# validating,  277 / 34433
# validating,  278 / 34433
# validating,  279 / 34433
# validating,  280 / 34433
# validating,  281 / 34433
# validating,  282 / 34433
# validating,  283 / 34433
# validating,  284 / 34433
# validating,  285 / 34433
# validating,  286 / 34433
# validating,  287 / 34433
# validating,  288 / 34433
# validating,  289 / 34433
# validating,  290 / 34433
# validating,  291 / 34433
# validating,  292 / 34433
# validating,  293 / 34433
# validating,  294 / 34433
# validating,  295 / 34433
# validating,  296 / 34433
# validating,  297 / 34433
# validating,  298 / 34433
# validating,  299 / 34433
# validating,  300 / 34433
# validating,  301 / 34433
# validating,  302 / 34433
# validating,  303 / 34433
# validating,  304 / 34433
# validating,  305 / 34433
# validating,  306 / 34433
# validating,  307 / 34433
# validating,  308 / 34433
# validating,  309 / 34433
# validating,  310 / 34433
# validating,  311 / 34433
# validating,  312 / 34433
# validating,  313 / 34433
# validating,  314 / 34433
# validating,  315 / 34433
# validating,  316 / 34433
# validating,  317 / 34433
# validating,  318 / 34433
# validating,  319 / 34433
# validating,  320 / 34433
# validating,  321 / 34433
# validating,  322 / 34433
# validating,  323 / 34433
# validating,  324 / 34433
# validating,  325 / 34433
# validating,  326 / 34433
# validating,  327 / 34433
# validating,  328 / 34433
# validating,  329 / 34433
# validating,  330 / 34433
# validating,  331 / 34433
# validating,  332 / 34433
# validating,  333 / 34433
# validating,  334 / 34433
# validating,  335 / 34433
# validating,  336 / 34433
# validating,  337 / 34433
# validating,  338 / 34433
# validating,  339 / 34433
# validating,  340 / 34433
# validating,  341 / 34433
# validating,  342 / 34433
# validating,  343 / 34433
# validating,  344 / 34433
# validating,  345 / 34433
# validating,  346 / 34433
# validating,  347 / 34433
# validating,  348 / 34433
# validating,  349 / 34433
# validating,  350 / 34433
# validating,  351 / 34433
# validating,  352 / 34433
# validating,  353 / 34433
# validating,  354 / 34433
# validating,  355 / 34433
# validating,  356 / 34433
# validating,  357 / 34433
# validating,  358 / 34433
# validating,  359 / 34433
# validating,  360 / 34433
# validating,  361 / 34433
# validating,  362 / 34433
# validating,  363 / 34433
# validating,  364 / 34433
# validating,  365 / 34433
# validating,  366 / 34433
# validating,  367 / 34433
# validating,  368 / 34433
# validating,  369 / 34433
# validating,  370 / 34433
# validating,  371 / 34433
# validating,  372 / 34433
# validating,  373 / 34433
# validating,  374 / 34433
# validating,  375 / 34433
# validating,  376 / 34433
# validating,  377 / 34433
# validating,  378 / 34433
# validating,  379 / 34433
# validating,  380 / 34433
# validating,  381 / 34433
# validating,  382 / 34433
# validating,  383 / 34433
# validating,  384 / 34433
# validating,  385 / 34433
# validating,  386 / 34433
# validating,  387 / 34433
# validating,  388 / 34433
# validating,  389 / 34433
# validating,  390 / 34433
# validating,  391 / 34433
# validating,  392 / 34433
# validating,  393 / 34433
# validating,  394 / 34433
# validating,  395 / 34433
# validating,  396 / 34433
# validating,  397 / 34433
# validating,  398 / 34433
# validating,  399 / 34433
# validating,  400 / 34433
# validating,  401 / 34433
# validating,  402 / 34433
# validating,  403 / 34433
# validating,  404 / 34433
# validating,  405 / 34433
# validating,  406 / 34433
# validating,  407 / 34433
# validating,  408 / 34433
# validating,  409 / 34433
# validating,  410 / 34433
# validating,  411 / 34433
# validating,  412 / 34433
# validating,  413 / 34433
# validating,  414 / 34433
# validating,  415 / 34433
# validating,  416 / 34433
# validating,  417 / 34433
# validating,  418 / 34433
# validating,  419 / 34433
# validating,  420 / 34433
# validating,  421 / 34433
# validating,  422 / 34433
# validating,  423 / 34433
# validating,  424 / 34433
# validating,  425 / 34433
# validating,  426 / 34433
# validating,  427 / 34433
# validating,  428 / 34433
# validating,  429 / 34433
# validating,  430 / 34433
# validating,  431 / 34433
# validating,  432 / 34433
# validating,  433 / 34433
# validating,  434 / 34433
# validating,  435 / 34433
# validating,  436 / 34433
# validating,  437 / 34433
# validating,  438 / 34433
# validating,  439 / 34433
# validating,  440 / 34433
# validating,  441 / 34433
# validating,  442 / 34433
# validating,  443 / 34433
# validating,  444 / 34433
# validating,  445 / 34433
# validating,  446 / 34433
# validating,  447 / 34433
# validating,  448 / 34433
# validating,  449 / 34433
# validating,  450 / 34433
# validating,  451 / 34433
# validating,  452 / 34433
# validating,  453 / 34433
# validating,  454 / 34433
# validating,  455 / 34433
# validating,  456 / 34433
# validating,  457 / 34433
# validating,  458 / 34433
# validating,  459 / 34433
# validating,  460 / 34433
# validating,  461 / 34433
# validating,  462 / 34433
# validating,  463 / 34433
# validating,  464 / 34433
# validating,  465 / 34433
# validating,  466 / 34433
# validating,  467 / 34433
# validating,  468 / 34433
# validating,  469 / 34433
# validating,  470 / 34433
# validating,  471 / 34433
# validating,  472 / 34433
# validating,  473 / 34433
# validating,  474 / 34433
# validating,  475 / 34433
# validating,  476 / 34433
# validating,  477 / 34433
# validating,  478 / 34433
# validating,  479 / 34433
# validating,  480 / 34433
# validating,  481 / 34433
# validating,  482 / 34433
# validating,  483 / 34433
# validating,  484 / 34433
# validating,  485 / 34433
# validating,  486 / 34433
# validating,  487 / 34433
# validating,  488 / 34433
# validating,  489 / 34433
# validating,  490 / 34433
# validating,  491 / 34433
# validating,  492 / 34433
# validating,  493 / 34433
# validating,  494 / 34433
# validating,  495 / 34433
# validating,  496 / 34433
# validating,  497 / 34433
# validating,  498 / 34433
# validating,  499 / 34433
# validating,  500 / 34433
# validating,  501 / 34433
# validating,  502 / 34433
# validating,  503 / 34433
# validating,  504 / 34433
# validating,  505 / 34433
# validating,  506 / 34433
# validating,  507 / 34433
# validating,  508 / 34433
# validating,  509 / 34433
# validating,  510 / 34433
# validating,  511 / 34433
# validating,  512 / 34433
# validating,  513 / 34433
# validating,  514 / 34433
# validating,  515 / 34433
# validating,  516 / 34433
# validating,  517 / 34433
# validating,  518 / 34433
# validating,  519 / 34433
# validating,  520 / 34433
# validating,  521 / 34433
# validating,  522 / 34433
# validating,  523 / 34433
# validating,  524 / 34433
# validating,  525 / 34433
# validating,  526 / 34433
# validating,  527 / 34433
# validating,  528 / 34433
# validating,  529 / 34433
# validating,  530 / 34433
# validating,  531 / 34433
# validating,  532 / 34433
# validating,  533 / 34433
# validating,  534 / 34433
# validating,  535 / 34433
# validating,  536 / 34433
# validating,  537 / 34433
# validating,  538 / 34433
# validating,  539 / 34433
# validating,  540 / 34433
# validating,  541 / 34433
# validating,  542 / 34433
# validating,  543 / 34433
# validating,  544 / 34433
# validating,  545 / 34433
# validating,  546 / 34433
# validating,  547 / 34433
# validating,  548 / 34433
# validating,  549 / 34433
# validating,  550 / 34433
# validating,  551 / 34433
# validating,  552 / 34433
# validating,  553 / 34433
# validating,  554 / 34433
# validating,  555 / 34433
# validating,  556 / 34433
# validating,  557 / 34433
# validating,  558 / 34433
# validating,  559 / 34433
# validating,  560 / 34433
# validating,  561 / 34433
# validating,  562 / 34433
# validating,  563 / 34433
# validating,  564 / 34433
# validating,  565 / 34433
# validating,  566 / 34433
# validating,  567 / 34433
# validating,  568 / 34433
# validating,  569 / 34433
# validating,  570 / 34433
# validating,  571 / 34433
# validating,  572 / 34433
# validating,  573 / 34433
# validating,  574 / 34433
# validating,  575 / 34433
# validating,  576 / 34433
# validating,  577 / 34433
# validating,  578 / 34433
# validating,  579 / 34433
# validating,  580 / 34433
# validating,  581 / 34433
# validating,  582 / 34433
# validating,  583 / 34433
# validating,  584 / 34433
# validating,  585 / 34433
# validating,  586 / 34433
# validating,  587 / 34433
# validating,  588 / 34433
# validating,  589 / 34433
# validating,  590 / 34433
# validating,  591 / 34433
# validating,  592 / 34433
# validating,  593 / 34433
# validating,  594 / 34433
# validating,  595 / 34433
# validating,  596 / 34433
# validating,  597 / 34433
# validating,  598 / 34433
# validating,  599 / 34433
# validating,  600 / 34433
# validating,  601 / 34433
# validating,  602 / 34433
# validating,  603 / 34433
# validating,  604 / 34433
# validating,  605 / 34433
# validating,  606 / 34433
# validating,  607 / 34433
# validating,  608 / 34433
# validating,  609 / 34433
# validating,  610 / 34433
# validating,  611 / 34433
# validating,  612 / 34433
# validating,  613 / 34433
# validating,  614 / 34433
# validating,  615 / 34433
# validating,  616 / 34433
# validating,  617 / 34433
# validating,  618 / 34433
# validating,  619 / 34433
# validating,  620 / 34433
# validating,  621 / 34433
# validating,  622 / 34433
# validating,  623 / 34433
# validating,  624 / 34433
# validating,  625 / 34433
# validating,  626 / 34433
# validating,  627 / 34433
# validating,  628 / 34433
# validating,  629 / 34433
# validating,  630 / 34433
# validating,  631 / 34433
# validating,  632 / 34433
# validating,  633 / 34433
# validating,  634 / 34433
# validating,  635 / 34433
# validating,  636 / 34433
# validating,  637 / 34433
# validating,  638 / 34433
# validating,  639 / 34433
# validating,  640 / 34433
# validating,  641 / 34433
# validating,  642 / 34433
# validating,  643 / 34433
# validating,  644 / 34433
# validating,  645 / 34433
# validating,  646 / 34433
# validating,  647 / 34433
# validating,  648 / 34433
# validating,  649 / 34433
# validating,  650 / 34433
# validating,  651 / 34433
# validating,  652 / 34433
# validating,  653 / 34433
# validating,  654 / 34433
# validating,  655 / 34433
# validating,  656 / 34433
# validating,  657 / 34433
# validating,  658 / 34433
# validating,  659 / 34433
# validating,  660 / 34433
# validating,  661 / 34433
# validating,  662 / 34433
# validating,  663 / 34433
# validating,  664 / 34433
# validating,  665 / 34433
# validating,  666 / 34433
# validating,  667 / 34433
# validating,  668 / 34433
# validating,  669 / 34433
# validating,  670 / 34433
# validating,  671 / 34433
# validating,  672 / 34433
# validating,  673 / 34433
# validating,  674 / 34433
# validating,  675 / 34433
# validating,  676 / 34433
# validating,  677 / 34433
# validating,  678 / 34433
# validating,  679 / 34433
# validating,  680 / 34433
# validating,  681 / 34433
# validating,  682 / 34433
# validating,  683 / 34433
# validating,  684 / 34433
# validating,  685 / 34433
# validating,  686 / 34433
# validating,  687 / 34433
# validating,  688 / 34433
# validating,  689 / 34433
# validating,  690 / 34433
# validating,  691 / 34433
# validating,  692 / 34433
# validating,  693 / 34433
# validating,  694 / 34433
# validating,  695 / 34433
# validating,  696 / 34433
# validating,  697 / 34433
# validating,  698 / 34433
# validating,  699 / 34433
# validating,  700 / 34433
# validating,  701 / 34433
# validating,  702 / 34433
# validating,  703 / 34433
# validating,  704 / 34433
# validating,  705 / 34433
# validating,  706 / 34433
# validating,  707 / 34433
# validating,  708 / 34433
# validating,  709 / 34433
# validating,  710 / 34433
# validating,  711 / 34433
# validating,  712 / 34433
# validating,  713 / 34433
# validating,  714 / 34433
# validating,  715 / 34433
# validating,  716 / 34433
# validating,  717 / 34433
# validating,  718 / 34433
# validating,  719 / 34433
# validating,  720 / 34433
# validating,  721 / 34433
# validating,  722 / 34433
# validating,  723 / 34433
# validating,  724 / 34433
# validating,  725 / 34433
# validating,  726 / 34433
# validating,  727 / 34433
# validating,  728 / 34433
# validating,  729 / 34433
# validating,  730 / 34433
# validating,  731 / 34433
# validating,  732 / 34433
# validating,  733 / 34433
# validating,  734 / 34433
# validating,  735 / 34433
# validating,  736 / 34433
# validating,  737 / 34433
# validating,  738 / 34433
# validating,  739 / 34433
# validating,  740 / 34433
# validating,  741 / 34433
# validating,  742 / 34433
# validating,  743 / 34433
# validating,  744 / 34433
# validating,  745 / 34433
# validating,  746 / 34433
# validating,  747 / 34433
# validating,  748 / 34433
# validating,  749 / 34433
# validating,  750 / 34433
# validating,  751 / 34433
# validating,  752 / 34433
# validating,  753 / 34433
# validating,  754 / 34433
# validating,  755 / 34433
# validating,  756 / 34433
# validating,  757 / 34433
# validating,  758 / 34433
# validating,  759 / 34433
# validating,  760 / 34433
# validating,  761 / 34433
# validating,  762 / 34433
# validating,  763 / 34433
# validating,  764 / 34433
# validating,  765 / 34433
# validating,  766 / 34433
# validating,  767 / 34433
# validating,  768 / 34433
# validating,  769 / 34433
# validating,  770 / 34433
# validating,  771 / 34433
# validating,  772 / 34433
# validating,  773 / 34433
# validating,  774 / 34433
# validating,  775 / 34433
# validating,  776 / 34433
# validating,  777 / 34433
# validating,  778 / 34433
# validating,  779 / 34433
# validating,  780 / 34433
# validating,  781 / 34433
# validating,  782 / 34433
# validating,  783 / 34433
# validating,  784 / 34433
# validating,  785 / 34433
# validating,  786 / 34433
# validating,  787 / 34433
# validating,  788 / 34433
# validating,  789 / 34433
# validating,  790 / 34433
# validating,  791 / 34433
# validating,  792 / 34433
# validating,  793 / 34433
# validating,  794 / 34433
# validating,  795 / 34433
# validating,  796 / 34433
# validating,  797 / 34433
# validating,  798 / 34433
# validating,  799 / 34433
# validating,  800 / 34433
# validating,  801 / 34433
# validating,  802 / 34433
# validating,  803 / 34433
# validating,  804 / 34433
# validating,  805 / 34433
# validating,  806 / 34433
# validating,  807 / 34433
# validating,  808 / 34433
# validating,  809 / 34433
# validating,  810 / 34433
# validating,  811 / 34433
# validating,  812 / 34433
# validating,  813 / 34433
# validating,  814 / 34433
# validating,  815 / 34433
# validating,  816 / 34433
# validating,  817 / 34433
# validating,  818 / 34433
# validating,  819 / 34433
# validating,  820 / 34433
# validating,  821 / 34433
# validating,  822 / 34433
# validating,  823 / 34433
# validating,  824 / 34433
# validating,  825 / 34433
# validating,  826 / 34433
# validating,  827 / 34433
# validating,  828 / 34433
# validating,  829 / 34433
# validating,  830 / 34433
# validating,  831 / 34433
# validating,  832 / 34433
# validating,  833 / 34433
# validating,  834 / 34433
# validating,  835 / 34433
# validating,  836 / 34433
# validating,  837 / 34433
# validating,  838 / 34433
# validating,  839 / 34433
# validating,  840 / 34433
# validating,  841 / 34433
# validating,  842 / 34433
# validating,  843 / 34433
# validating,  844 / 34433
# validating,  845 / 34433
# validating,  846 / 34433
# validating,  847 / 34433
# validating,  848 / 34433
# validating,  849 / 34433
# validating,  850 / 34433
# validating,  851 / 34433
# validating,  852 / 34433
# validating,  853 / 34433
# validating,  854 / 34433
# validating,  855 / 34433
# validating,  856 / 34433
# validating,  857 / 34433
# validating,  858 / 34433
# validating,  859 / 34433
# validating,  860 / 34433
# validating,  861 / 34433
# validating,  862 / 34433
# validating,  863 / 34433
# validating,  864 / 34433
# validating,  865 / 34433
# validating,  866 / 34433
# validating,  867 / 34433
# validating,  868 / 34433
# validating,  869 / 34433
# validating,  870 / 34433
# validating,  871 / 34433
# validating,  872 / 34433
# validating,  873 / 34433
# validating,  874 / 34433
# validating,  875 / 34433
# validating,  876 / 34433
# validating,  877 / 34433
# validating,  878 / 34433
# validating,  879 / 34433
# validating,  880 / 34433
# validating,  881 / 34433
# validating,  882 / 34433
# validating,  883 / 34433
# validating,  884 / 34433
# validating,  885 / 34433
# validating,  886 / 34433
# validating,  887 / 34433
# validating,  888 / 34433
# validating,  889 / 34433
# validating,  890 / 34433
# validating,  891 / 34433
# validating,  892 / 34433
# validating,  893 / 34433
# validating,  894 / 34433
# validating,  895 / 34433
# validating,  896 / 34433
# validating,  897 / 34433
# validating,  898 / 34433
# validating,  899 / 34433
# validating,  900 / 34433
# validating,  901 / 34433
# validating,  902 / 34433
# validating,  903 / 34433
# validating,  904 / 34433
# validating,  905 / 34433
# validating,  906 / 34433
# validating,  907 / 34433
# validating,  908 / 34433
# validating,  909 / 34433
# validating,  910 / 34433
# validating,  911 / 34433
# validating,  912 / 34433
# validating,  913 / 34433
# validating,  914 / 34433
# validating,  915 / 34433
# validating,  916 / 34433
# validating,  917 / 34433
# validating,  918 / 34433
# validating,  919 / 34433
# validating,  920 / 34433
# validating,  921 / 34433
# validating,  922 / 34433
# validating,  923 / 34433
# validating,  924 / 34433
# validating,  925 / 34433
# validating,  926 / 34433
# validating,  927 / 34433
# validating,  928 / 34433
# validating,  929 / 34433
# validating,  930 / 34433
# validating,  931 / 34433
# validating,  932 / 34433
# validating,  933 / 34433
# validating,  934 / 34433
# validating,  935 / 34433
# validating,  936 / 34433
# validating,  937 / 34433
# validating,  938 / 34433
# validating,  939 / 34433
# validating,  940 / 34433
# validating,  941 / 34433
# validating,  942 / 34433
# validating,  943 / 34433
# validating,  944 / 34433
# validating,  945 / 34433
# validating,  946 / 34433
# validating,  947 / 34433
# validating,  948 / 34433
# validating,  949 / 34433
# validating,  950 / 34433
# validating,  951 / 34433
# validating,  952 / 34433
# validating,  953 / 34433
# validating,  954 / 34433
# validating,  955 / 34433
# validating,  956 / 34433
# validating,  957 / 34433
# validating,  958 / 34433
# validating,  959 / 34433
# validating,  960 / 34433
# validating,  961 / 34433
# validating,  962 / 34433
# validating,  963 / 34433
# validating,  964 / 34433
# validating,  965 / 34433
# validating,  966 / 34433
# validating,  967 / 34433
# validating,  968 / 34433
# validating,  969 / 34433
# validating,  970 / 34433
# validating,  971 / 34433
# validating,  972 / 34433
# validating,  973 / 34433
# validating,  974 / 34433
# validating,  975 / 34433
# validating,  976 / 34433
# validating,  977 / 34433
# validating,  978 / 34433
# validating,  979 / 34433
# validating,  980 / 34433
# validating,  981 / 34433
# validating,  982 / 34433
# validating,  983 / 34433
# validating,  984 / 34433
# validating,  985 / 34433
# validating,  986 / 34433
# validating,  987 / 34433
# validating,  988 / 34433
# validating,  989 / 34433
# validating,  990 / 34433
# validating,  991 / 34433
# validating,  992 / 34433
# validating,  993 / 34433
# validating,  994 / 34433
# validating,  995 / 34433
# validating,  996 / 34433
# validating,  997 / 34433
# validating,  998 / 34433
# validating,  999 / 34433
# validating,  1000 / 34433
# validating,  1001 / 34433
# validating,  1002 / 34433
# validating,  1003 / 34433
# validating,  1004 / 34433
# validating,  1005 / 34433
# validating,  1006 / 34433
# validating,  1007 / 34433
# validating,  1008 / 34433
# validating,  1009 / 34433
# validating,  1010 / 34433
# validating,  1011 / 34433
# validating,  1012 / 34433
# validating,  1013 / 34433
# validating,  1014 / 34433
# validating,  1015 / 34433
# validating,  1016 / 34433
# validating,  1017 / 34433
# validating,  1018 / 34433
# validating,  1019 / 34433
# validating,  1020 / 34433
# validating,  1021 / 34433
# validating,  1022 / 34433
# validating,  1023 / 34433
# validating,  1024 / 34433
# validating,  1025 / 34433
# validating,  1026 / 34433
# validating,  1027 / 34433
# validating,  1028 / 34433
# validating,  1029 / 34433
# validating,  1030 / 34433
# validating,  1031 / 34433
# validating,  1032 / 34433
# validating,  1033 / 34433
# validating,  1034 / 34433
# validating,  1035 / 34433
# validating,  1036 / 34433
# validating,  1037 / 34433
# validating,  1038 / 34433
# validating,  1039 / 34433
# validating,  1040 / 34433
# validating,  1041 / 34433
# validating,  1042 / 34433
# validating,  1043 / 34433
# validating,  1044 / 34433
# validating,  1045 / 34433
# validating,  1046 / 34433
# validating,  1047 / 34433
# validating,  1048 / 34433
# validating,  1049 / 34433
# validating,  1050 / 34433
# validating,  1051 / 34433
# validating,  1052 / 34433
# validating,  1053 / 34433
# validating,  1054 / 34433
# validating,  1055 / 34433
# validating,  1056 / 34433
# validating,  1057 / 34433
# validating,  1058 / 34433
# validating,  1059 / 34433
# validating,  1060 / 34433
# validating,  1061 / 34433
# validating,  1062 / 34433
# validating,  1063 / 34433
# validating,  1064 / 34433
# validating,  1065 / 34433
# validating,  1066 / 34433
# validating,  1067 / 34433
# validating,  1068 / 34433
# validating,  1069 / 34433
# validating,  1070 / 34433
# validating,  1071 / 34433
# validating,  1072 / 34433
# validating,  1073 / 34433
# validating,  1074 / 34433
# validating,  1075 / 34433
# validating,  1076 / 34433
# validating,  1077 / 34433
# validating,  1078 / 34433
# validating,  1079 / 34433
# validating,  1080 / 34433
# validating,  1081 / 34433
# validating,  1082 / 34433
# validating,  1083 / 34433
# validating,  1084 / 34433
# validating,  1085 / 34433
# validating,  1086 / 34433
# validating,  1087 / 34433
# validating,  1088 / 34433
# validating,  1089 / 34433
# validating,  1090 / 34433
# validating,  1091 / 34433
# validating,  1092 / 34433
# validating,  1093 / 34433
# validating,  1094 / 34433
# validating,  1095 / 34433
# validating,  1096 / 34433
# validating,  1097 / 34433
# validating,  1098 / 34433
# validating,  1099 / 34433
# validating,  1100 / 34433
# validating,  1101 / 34433
# validating,  1102 / 34433
# validating,  1103 / 34433
# validating,  1104 / 34433
# validating,  1105 / 34433
# validating,  1106 / 34433
# validating,  1107 / 34433
# validating,  1108 / 34433
# validating,  1109 / 34433
# validating,  1110 / 34433
# validating,  1111 / 34433
# validating,  1112 / 34433
# validating,  1113 / 34433
# validating,  1114 / 34433
# validating,  1115 / 34433
# validating,  1116 / 34433
# validating,  1117 / 34433
# validating,  1118 / 34433
# validating,  1119 / 34433
# validating,  1120 / 34433
# validating,  1121 / 34433
# validating,  1122 / 34433
# validating,  1123 / 34433
# validating,  1124 / 34433
# validating,  1125 / 34433
# validating,  1126 / 34433
# validating,  1127 / 34433
# validating,  1128 / 34433
# validating,  1129 / 34433
# validating,  1130 / 34433
# validating,  1131 / 34433
# validating,  1132 / 34433
# validating,  1133 / 34433
# validating,  1134 / 34433
# validating,  1135 / 34433
# validating,  1136 / 34433
# validating,  1137 / 34433
# validating,  1138 / 34433
# validating,  1139 / 34433
# validating,  1140 / 34433
# validating,  1141 / 34433
# validating,  1142 / 34433
# validating,  1143 / 34433
# validating,  1144 / 34433
# validating,  1145 / 34433
# validating,  1146 / 34433
# validating,  1147 / 34433
# validating,  1148 / 34433
# validating,  1149 / 34433
# validating,  1150 / 34433
# validating,  1151 / 34433
# validating,  1152 / 34433
# validating,  1153 / 34433
# validating,  1154 / 34433
# validating,  1155 / 34433
# validating,  1156 / 34433
# validating,  1157 / 34433
# validating,  1158 / 34433
# validating,  1159 / 34433
# validating,  1160 / 34433
# validating,  1161 / 34433
# validating,  1162 / 34433
# validating,  1163 / 34433
# validating,  1164 / 34433
# validating,  1165 / 34433
# validating,  1166 / 34433
# validating,  1167 / 34433
# validating,  1168 / 34433
# validating,  1169 / 34433
# validating,  1170 / 34433
# validating,  1171 / 34433
# validating,  1172 / 34433
# validating,  1173 / 34433
# validating,  1174 / 34433
# validating,  1175 / 34433
# validating,  1176 / 34433
# validating,  1177 / 34433
# validating,  1178 / 34433
# validating,  1179 / 34433
# validating,  1180 / 34433
# validating,  1181 / 34433
# validating,  1182 / 34433
# validating,  1183 / 34433
# validating,  1184 / 34433
# validating,  1185 / 34433
# validating,  1186 / 34433
# validating,  1187 / 34433
# validating,  1188 / 34433
# validating,  1189 / 34433
# validating,  1190 / 34433
# validating,  1191 / 34433
# validating,  1192 / 34433
# validating,  1193 / 34433
# validating,  1194 / 34433
# validating,  1195 / 34433
# validating,  1196 / 34433
# validating,  1197 / 34433
# validating,  1198 / 34433
# validating,  1199 / 34433
# validating,  1200 / 34433
# validating,  1201 / 34433
# validating,  1202 / 34433
# validating,  1203 / 34433
# validating,  1204 / 34433
# validating,  1205 / 34433
# validating,  1206 / 34433
# validating,  1207 / 34433
# validating,  1208 / 34433
# validating,  1209 / 34433
# validating,  1210 / 34433
# validating,  1211 / 34433
# validating,  1212 / 34433
# validating,  1213 / 34433
# validating,  1214 / 34433
# validating,  1215 / 34433
# validating,  1216 / 34433
# validating,  1217 / 34433
# validating,  1218 / 34433
# validating,  1219 / 34433
# validating,  1220 / 34433
# validating,  1221 / 34433
# validating,  1222 / 34433
# validating,  1223 / 34433
# validating,  1224 / 34433
# validating,  1225 / 34433
# validating,  1226 / 34433
# validating,  1227 / 34433
# validating,  1228 / 34433
# validating,  1229 / 34433
# validating,  1230 / 34433
# validating,  1231 / 34433
# validating,  1232 / 34433
# validating,  1233 / 34433
# validating,  1234 / 34433
# validating,  1235 / 34433
# validating,  1236 / 34433
# validating,  1237 / 34433
# validating,  1238 / 34433
# validating,  1239 / 34433
# validating,  1240 / 34433
# validating,  1241 / 34433
# validating,  1242 / 34433
# validating,  1243 / 34433
# validating,  1244 / 34433
# validating,  1245 / 34433
# validating,  1246 / 34433
# validating,  1247 / 34433
# validating,  1248 / 34433
# validating,  1249 / 34433
# validating,  1250 / 34433
# validating,  1251 / 34433
# validating,  1252 / 34433
# validating,  1253 / 34433
# validating,  1254 / 34433
# validating,  1255 / 34433
# validating,  1256 / 34433
# validating,  1257 / 34433
# validating,  1258 / 34433
# validating,  1259 / 34433
# validating,  1260 / 34433
# validating,  1261 / 34433
# validating,  1262 / 34433
# validating,  1263 / 34433
# validating,  1264 / 34433
# validating,  1265 / 34433
# validating,  1266 / 34433
# validating,  1267 / 34433
# validating,  1268 / 34433
# validating,  1269 / 34433
# validating,  1270 / 34433
# validating,  1271 / 34433
# validating,  1272 / 34433
# validating,  1273 / 34433
# validating,  1274 / 34433
# validating,  1275 / 34433
# validating,  1276 / 34433
# validating,  1277 / 34433
# validating,  1278 / 34433
# validating,  1279 / 34433
# validating,  1280 / 34433
# validating,  1281 / 34433
# validating,  1282 / 34433
# validating,  1283 / 34433
# validating,  1284 / 34433
# validating,  1285 / 34433
# validating,  1286 / 34433
# validating,  1287 / 34433
# validating,  1288 / 34433
# validating,  1289 / 34433
# validating,  1290 / 34433
# validating,  1291 / 34433
# validating,  1292 / 34433
# validating,  1293 / 34433
# validating,  1294 / 34433
# validating,  1295 / 34433
# validating,  1296 / 34433
# validating,  1297 / 34433
# validating,  1298 / 34433
# validating,  1299 / 34433
# validating,  1300 / 34433
# validating,  1301 / 34433
# validating,  1302 / 34433
# validating,  1303 / 34433
# validating,  1304 / 34433
# validating,  1305 / 34433
# validating,  1306 / 34433
# validating,  1307 / 34433
# validating,  1308 / 34433
# validating,  1309 / 34433
# validating,  1310 / 34433
# validating,  1311 / 34433
# validating,  1312 / 34433
# validating,  1313 / 34433
# validating,  1314 / 34433
# validating,  1315 / 34433
# validating,  1316 / 34433
# validating,  1317 / 34433
# validating,  1318 / 34433
# validating,  1319 / 34433
# validating,  1320 / 34433
# validating,  1321 / 34433
# validating,  1322 / 34433
# validating,  1323 / 34433
# validating,  1324 / 34433
# validating,  1325 / 34433
# validating,  1326 / 34433
# validating,  1327 / 34433
# validating,  1328 / 34433
# validating,  1329 / 34433
# validating,  1330 / 34433
# validating,  1331 / 34433
# validating,  1332 / 34433
# validating,  1333 / 34433
# validating,  1334 / 34433
# validating,  1335 / 34433
# validating,  1336 / 34433
# validating,  1337 / 34433
# validating,  1338 / 34433
# validating,  1339 / 34433
# validating,  1340 / 34433
# validating,  1341 / 34433
# validating,  1342 / 34433
# validating,  1343 / 34433
# validating,  1344 / 34433
# validating,  1345 / 34433
# validating,  1346 / 34433
# validating,  1347 / 34433
# validating,  1348 / 34433
# validating,  1349 / 34433
# validating,  1350 / 34433
# validating,  1351 / 34433
# validating,  1352 / 34433
# validating,  1353 / 34433
# validating,  1354 / 34433
# validating,  1355 / 34433
# validating,  1356 / 34433
# validating,  1357 / 34433
# validating,  1358 / 34433
# validating,  1359 / 34433
# validating,  1360 / 34433
# validating,  1361 / 34433
# validating,  1362 / 34433
# validating,  1363 / 34433
# validating,  1364 / 34433
# validating,  1365 / 34433
# validating,  1366 / 34433
# validating,  1367 / 34433
# validating,  1368 / 34433
# validating,  1369 / 34433
# validating,  1370 / 34433
# validating,  1371 / 34433
# validating,  1372 / 34433
# validating,  1373 / 34433
# validating,  1374 / 34433
# validating,  1375 / 34433
# validating,  1376 / 34433
# validating,  1377 / 34433
# validating,  1378 / 34433
# validating,  1379 / 34433
# validating,  1380 / 34433
# validating,  1381 / 34433
# validating,  1382 / 34433
# validating,  1383 / 34433
# validating,  1384 / 34433
# validating,  1385 / 34433
# validating,  1386 / 34433
# validating,  1387 / 34433
# validating,  1388 / 34433
# validating,  1389 / 34433
# validating,  1390 / 34433
# validating,  1391 / 34433
# validating,  1392 / 34433
# validating,  1393 / 34433
# validating,  1394 / 34433
# validating,  1395 / 34433
# validating,  1396 / 34433
# validating,  1397 / 34433
# validating,  1398 / 34433
# validating,  1399 / 34433
# validating,  1400 / 34433
# validating,  1401 / 34433
# validating,  1402 / 34433
# validating,  1403 / 34433
# validating,  1404 / 34433
# validating,  1405 / 34433
# validating,  1406 / 34433
# validating,  1407 / 34433
# validating,  1408 / 34433
# validating,  1409 / 34433
# validating,  1410 / 34433
# validating,  1411 / 34433
# validating,  1412 / 34433
# validating,  1413 / 34433
# validating,  1414 / 34433
# validating,  1415 / 34433
# validating,  1416 / 34433
# validating,  1417 / 34433
# validating,  1418 / 34433
# validating,  1419 / 34433
# validating,  1420 / 34433
# validating,  1421 / 34433
# validating,  1422 / 34433
# validating,  1423 / 34433
# validating,  1424 / 34433
# validating,  1425 / 34433
# validating,  1426 / 34433
# validating,  1427 / 34433
# validating,  1428 / 34433
# validating,  1429 / 34433
# validating,  1430 / 34433
# validating,  1431 / 34433
# validating,  1432 / 34433
# validating,  1433 / 34433
# validating,  1434 / 34433
# validating,  1435 / 34433
# validating,  1436 / 34433
# validating,  1437 / 34433
# validating,  1438 / 34433
# validating,  1439 / 34433
# validating,  1440 / 34433
# validating,  1441 / 34433
# validating,  1442 / 34433
# validating,  1443 / 34433
# validating,  1444 / 34433
# validating,  1445 / 34433
# validating,  1446 / 34433
# validating,  1447 / 34433
# validating,  1448 / 34433
# validating,  1449 / 34433
# validating,  1450 / 34433
# validating,  1451 / 34433
# validating,  1452 / 34433
# validating,  1453 / 34433
# validating,  1454 / 34433
# validating,  1455 / 34433
# validating,  1456 / 34433
# validating,  1457 / 34433
# validating,  1458 / 34433
# validating,  1459 / 34433
# validating,  1460 / 34433
# validating,  1461 / 34433
# validating,  1462 / 34433
# validating,  1463 / 34433
# validating,  1464 / 34433
# validating,  1465 / 34433
# validating,  1466 / 34433
# validating,  1467 / 34433
# validating,  1468 / 34433
# validating,  1469 / 34433
# validating,  1470 / 34433
# validating,  1471 / 34433
# validating,  1472 / 34433
# validating,  1473 / 34433
# validating,  1474 / 34433
# validating,  1475 / 34433
# validating,  1476 / 34433
# validating,  1477 / 34433
# validating,  1478 / 34433
# validating,  1479 / 34433
# validating,  1480 / 34433
# validating,  1481 / 34433
# validating,  1482 / 34433
# validating,  1483 / 34433
# validating,  1484 / 34433
# validating,  1485 / 34433
# validating,  1486 / 34433
# validating,  1487 / 34433
# validating,  1488 / 34433
# validating,  1489 / 34433
# validating,  1490 / 34433
# validating,  1491 / 34433
# validating,  1492 / 34433
# validating,  1493 / 34433
# validating,  1494 / 34433
# validating,  1495 / 34433
# validating,  1496 / 34433
# validating,  1497 / 34433
# validating,  1498 / 34433
# validating,  1499 / 34433
# validating,  1500 / 34433
# validating,  1501 / 34433
# validating,  1502 / 34433
# validating,  1503 / 34433
# validating,  1504 / 34433
# validating,  1505 / 34433
# validating,  1506 / 34433
# validating,  1507 / 34433
# validating,  1508 / 34433
# validating,  1509 / 34433
# validating,  1510 / 34433
# validating,  1511 / 34433
# validating,  1512 / 34433
# validating,  1513 / 34433
# validating,  1514 / 34433
# validating,  1515 / 34433
# validating,  1516 / 34433
# validating,  1517 / 34433
# validating,  1518 / 34433
# validating,  1519 / 34433
# validating,  1520 / 34433
# validating,  1521 / 34433
# validating,  1522 / 34433
# validating,  1523 / 34433
# validating,  1524 / 34433
# validating,  1525 / 34433
# validating,  1526 / 34433
# validating,  1527 / 34433
# validating,  1528 / 34433
# validating,  1529 / 34433
# validating,  1530 / 34433
# validating,  1531 / 34433
# validating,  1532 / 34433
# validating,  1533 / 34433
# validating,  1534 / 34433
# validating,  1535 / 34433
# validating,  1536 / 34433
# validating,  1537 / 34433
# validating,  1538 / 34433
# validating,  1539 / 34433
# validating,  1540 / 34433
# validating,  1541 / 34433
# validating,  1542 / 34433
# validating,  1543 / 34433
# validating,  1544 / 34433
# validating,  1545 / 34433
# validating,  1546 / 34433
# validating,  1547 / 34433
# validating,  1548 / 34433
# validating,  1549 / 34433
# validating,  1550 / 34433
# validating,  1551 / 34433
# validating,  1552 / 34433
# validating,  1553 / 34433
# validating,  1554 / 34433
# validating,  1555 / 34433
# validating,  1556 / 34433
# validating,  1557 / 34433
# validating,  1558 / 34433
# validating,  1559 / 34433
# validating,  1560 / 34433
# validating,  1561 / 34433
# validating,  1562 / 34433
# validating,  1563 / 34433
# validating,  1564 / 34433
# validating,  1565 / 34433
# validating,  1566 / 34433
# validating,  1567 / 34433
# validating,  1568 / 34433
# validating,  1569 / 34433
# validating,  1570 / 34433
# validating,  1571 / 34433
# validating,  1572 / 34433
# validating,  1573 / 34433
# validating,  1574 / 34433
# validating,  1575 / 34433
# validating,  1576 / 34433
# validating,  1577 / 34433
# validating,  1578 / 34433
# validating,  1579 / 34433
# validating,  1580 / 34433
# validating,  1581 / 34433
# validating,  1582 / 34433
# validating,  1583 / 34433
# validating,  1584 / 34433
# validating,  1585 / 34433
# validating,  1586 / 34433
# validating,  1587 / 34433
# validating,  1588 / 34433
# validating,  1589 / 34433
# validating,  1590 / 34433
# validating,  1591 / 34433
# validating,  1592 / 34433
# validating,  1593 / 34433
# validating,  1594 / 34433
# validating,  1595 / 34433
# validating,  1596 / 34433
# validating,  1597 / 34433
# validating,  1598 / 34433
# validating,  1599 / 34433
# validating,  1600 / 34433
# validating,  1601 / 34433
# validating,  1602 / 34433
# validating,  1603 / 34433
# validating,  1604 / 34433
# validating,  1605 / 34433
# validating,  1606 / 34433
# validating,  1607 / 34433
# validating,  1608 / 34433
# validating,  1609 / 34433
# validating,  1610 / 34433
# validating,  1611 / 34433
# validating,  1612 / 34433
# validating,  1613 / 34433
# validating,  1614 / 34433
# validating,  1615 / 34433
# validating,  1616 / 34433
# validating,  1617 / 34433
# validating,  1618 / 34433
# validating,  1619 / 34433
# validating,  1620 / 34433
# validating,  1621 / 34433
# validating,  1622 / 34433
# validating,  1623 / 34433
# validating,  1624 / 34433
# validating,  1625 / 34433
# validating,  1626 / 34433
# validating,  1627 / 34433
# validating,  1628 / 34433
# validating,  1629 / 34433
# validating,  1630 / 34433
# validating,  1631 / 34433
# validating,  1632 / 34433
# validating,  1633 / 34433
# validating,  1634 / 34433
# validating,  1635 / 34433
# validating,  1636 / 34433
# validating,  1637 / 34433
# validating,  1638 / 34433
# validating,  1639 / 34433
# validating,  1640 / 34433
# validating,  1641 / 34433
# validating,  1642 / 34433
# validating,  1643 / 34433
# validating,  1644 / 34433
# validating,  1645 / 34433
# validating,  1646 / 34433
# validating,  1647 / 34433
# validating,  1648 / 34433
# validating,  1649 / 34433
# validating,  1650 / 34433
# validating,  1651 / 34433
# validating,  1652 / 34433
# validating,  1653 / 34433
# validating,  1654 / 34433
# validating,  1655 / 34433
# validating,  1656 / 34433
# validating,  1657 / 34433
# validating,  1658 / 34433
# validating,  1659 / 34433
# validating,  1660 / 34433
# validating,  1661 / 34433
# validating,  1662 / 34433
# validating,  1663 / 34433
# validating,  1664 / 34433
# validating,  1665 / 34433
# validating,  1666 / 34433
# validating,  1667 / 34433
# validating,  1668 / 34433
# validating,  1669 / 34433
# validating,  1670 / 34433
# validating,  1671 / 34433
# validating,  1672 / 34433
# validating,  1673 / 34433
# validating,  1674 / 34433
# validating,  1675 / 34433
# validating,  1676 / 34433
# validating,  1677 / 34433
# validating,  1678 / 34433
# validating,  1679 / 34433
# validating,  1680 / 34433
# validating,  1681 / 34433
# validating,  1682 / 34433
# validating,  1683 / 34433
# validating,  1684 / 34433
# validating,  1685 / 34433
# validating,  1686 / 34433
# validating,  1687 / 34433
# validating,  1688 / 34433
# validating,  1689 / 34433
# validating,  1690 / 34433
# validating,  1691 / 34433
# validating,  1692 / 34433
# validating,  1693 / 34433
# validating,  1694 / 34433
# validating,  1695 / 34433
# validating,  1696 / 34433
# validating,  1697 / 34433
# validating,  1698 / 34433
# validating,  1699 / 34433
# validating,  1700 / 34433
# validating,  1701 / 34433
# validating,  1702 / 34433
# validating,  1703 / 34433
# validating,  1704 / 34433
# validating,  1705 / 34433
# validating,  1706 / 34433
# validating,  1707 / 34433
# validating,  1708 / 34433
# validating,  1709 / 34433
# validating,  1710 / 34433
# validating,  1711 / 34433
# validating,  1712 / 34433
# validating,  1713 / 34433
# validating,  1714 / 34433
# validating,  1715 / 34433
# validating,  1716 / 34433
# validating,  1717 / 34433
# validating,  1718 / 34433
# validating,  1719 / 34433
# validating,  1720 / 34433
# validating,  1721 / 34433
# validating,  1722 / 34433
# validating,  1723 / 34433
# validating,  1724 / 34433
# validating,  1725 / 34433
# validating,  1726 / 34433
# validating,  1727 / 34433
# validating,  1728 / 34433
# validating,  1729 / 34433
# validating,  1730 / 34433
# validating,  1731 / 34433
# validating,  1732 / 34433
# validating,  1733 / 34433
# validating,  1734 / 34433
# validating,  1735 / 34433
# validating,  1736 / 34433
# validating,  1737 / 34433
# validating,  1738 / 34433
# validating,  1739 / 34433
# validating,  1740 / 34433
# validating,  1741 / 34433
# validating,  1742 / 34433
# validating,  1743 / 34433
# validating,  1744 / 34433
# validating,  1745 / 34433
# validating,  1746 / 34433
# validating,  1747 / 34433
# validating,  1748 / 34433
# validating,  1749 / 34433
# validating,  1750 / 34433
# validating,  1751 / 34433
# validating,  1752 / 34433
# validating,  1753 / 34433
# validating,  1754 / 34433
# validating,  1755 / 34433
# validating,  1756 / 34433
# validating,  1757 / 34433
# validating,  1758 / 34433
# validating,  1759 / 34433
# validating,  1760 / 34433
# validating,  1761 / 34433
# validating,  1762 / 34433
# validating,  1763 / 34433
# validating,  1764 / 34433
# validating,  1765 / 34433
# validating,  1766 / 34433
# validating,  1767 / 34433
# validating,  1768 / 34433
# validating,  1769 / 34433
# validating,  1770 / 34433
# validating,  1771 / 34433
# validating,  1772 / 34433
# validating,  1773 / 34433
# validating,  1774 / 34433
# validating,  1775 / 34433
# validating,  1776 / 34433
# validating,  1777 / 34433
# validating,  1778 / 34433
# validating,  1779 / 34433
# validating,  1780 / 34433
# validating,  1781 / 34433
# validating,  1782 / 34433
# validating,  1783 / 34433
# validating,  1784 / 34433
# validating,  1785 / 34433
# validating,  1786 / 34433
# validating,  1787 / 34433
# validating,  1788 / 34433
# validating,  1789 / 34433
# validating,  1790 / 34433
# validating,  1791 / 34433
# validating,  1792 / 34433
# validating,  1793 / 34433
# validating,  1794 / 34433
# validating,  1795 / 34433
# validating,  1796 / 34433
# validating,  1797 / 34433
# validating,  1798 / 34433
# validating,  1799 / 34433
# validating,  1800 / 34433
# validating,  1801 / 34433
# validating,  1802 / 34433
# validating,  1803 / 34433
# validating,  1804 / 34433
# validating,  1805 / 34433
# validating,  1806 / 34433
# validating,  1807 / 34433
# validating,  1808 / 34433
# validating,  1809 / 34433
# validating,  1810 / 34433
# validating,  1811 / 34433
# validating,  1812 / 34433
# validating,  1813 / 34433
# validating,  1814 / 34433
# validating,  1815 / 34433
# validating,  1816 / 34433
# validating,  1817 / 34433
# validating,  1818 / 34433
# validating,  1819 / 34433
# validating,  1820 / 34433
# validating,  1821 / 34433
# validating,  1822 / 34433
# validating,  1823 / 34433
# validating,  1824 / 34433
# validating,  1825 / 34433
# validating,  1826 / 34433
# validating,  1827 / 34433
# validating,  1828 / 34433
# validating,  1829 / 34433
# validating,  1830 / 34433
# validating,  1831 / 34433
# validating,  1832 / 34433
# validating,  1833 / 34433
# validating,  1834 / 34433
# validating,  1835 / 34433
# validating,  1836 / 34433
# validating,  1837 / 34433
# validating,  1838 / 34433
# validating,  1839 / 34433
# validating,  1840 / 34433
# validating,  1841 / 34433
# validating,  1842 / 34433
# validating,  1843 / 34433
# validating,  1844 / 34433
# validating,  1845 / 34433
# validating,  1846 / 34433
# validating,  1847 / 34433
# validating,  1848 / 34433
# validating,  1849 / 34433
# validating,  1850 / 34433
# validating,  1851 / 34433
# validating,  1852 / 34433
# validating,  1853 / 34433
# validating,  1854 / 34433
# validating,  1855 / 34433
# validating,  1856 / 34433
# validating,  1857 / 34433
# validating,  1858 / 34433
# validating,  1859 / 34433
# validating,  1860 / 34433
# validating,  1861 / 34433
# validating,  1862 / 34433
# validating,  1863 / 34433
# validating,  1864 / 34433
# validating,  1865 / 34433
# validating,  1866 / 34433
# validating,  1867 / 34433
# validating,  1868 / 34433
# validating,  1869 / 34433
# validating,  1870 / 34433
# validating,  1871 / 34433
# validating,  1872 / 34433
# validating,  1873 / 34433
# validating,  1874 / 34433
# validating,  1875 / 34433
# validating,  1876 / 34433
# validating,  1877 / 34433
# validating,  1878 / 34433
# validating,  1879 / 34433
# validating,  1880 / 34433
# validating,  1881 / 34433
# validating,  1882 / 34433
# validating,  1883 / 34433
# validating,  1884 / 34433
# validating,  1885 / 34433
# validating,  1886 / 34433
# validating,  1887 / 34433
# ...
# validating,  33841 / 34433
# validating,  33842 / 34433
# validating,  33843 / 34433
# validating,  33844 / 34433
# validating,  33845 / 34433
# validating,  33846 / 34433
# validating,  33847 / 34433
# validating,  33848 / 34433
# validating,  33849 / 34433
# validating,  33850 / 34433
# validating,  33851 / 34433
# validating,  33852 / 34433
# validating,  33853 / 34433
# validating,  33854 / 34433
# validating,  33855 / 34433
# validating,  33856 / 34433
# validating,  33857 / 34433
# validating,  33858 / 34433
# validating,  33859 / 34433
# validating,  33860 / 34433
# validating,  33861 / 34433
# validating,  33862 / 34433
# validating,  33863 / 34433
# validating,  33864 / 34433
# validating,  33865 / 34433
# validating,  33866 / 34433
# validating,  33867 / 34433
# validating,  33868 / 34433
# validating,  33869 / 34433
# validating,  33870 / 34433
# validating,  33871 / 34433
# validating,  33872 / 34433
# validating,  33873 / 34433
# validating,  33874 / 34433
# validating,  33875 / 34433
# validating,  33876 / 34433
# validating,  33877 / 34433
# validating,  33878 / 34433
# validating,  33879 / 34433
# validating,  33880 / 34433
# validating,  33881 / 34433
# validating,  33882 / 34433
# validating,  33883 / 34433
# validating,  33884 / 34433
# validating,  33885 / 34433
# validating,  33886 / 34433
# validating,  33887 / 34433
# validating,  33888 / 34433
# validating,  33889 / 34433
# validating,  33890 / 34433
# validating,  33891 / 34433
# validating,  33892 / 34433
# validating,  33893 / 34433
# validating,  33894 / 34433
# validating,  33895 / 34433
# validating,  33896 / 34433
# validating,  33897 / 34433
# validating,  33898 / 34433
# validating,  33899 / 34433
# validating,  33900 / 34433
# validating,  33901 / 34433
# validating,  33902 / 34433
# validating,  33903 / 34433
# validating,  33904 / 34433
# validating,  33905 / 34433
# validating,  33906 / 34433
# validating,  33907 / 34433
# validating,  33908 / 34433
# validating,  33909 / 34433
# validating,  33910 / 34433
# validating,  33911 / 34433
# validating,  33912 / 34433
# validating,  33913 / 34433
# validating,  33914 / 34433
# validating,  33915 / 34433
# validating,  33916 / 34433
# validating,  33917 / 34433
# validating,  33918 / 34433
# validating,  33919 / 34433
# validating,  33920 / 34433
# validating,  33921 / 34433
# validating,  33922 / 34433
# validating,  33923 / 34433
# validating,  33924 / 34433
# validating,  33925 / 34433
# validating,  33926 / 34433
# validating,  33927 / 34433
# validating,  33928 / 34433
# validating,  33929 / 34433
# validating,  33930 / 34433
# validating,  33931 / 34433
# validating,  33932 / 34433
# validating,  33933 / 34433
# validating,  33934 / 34433
# validating,  33935 / 34433
# validating,  33936 / 34433
# validating,  33937 / 34433
# validating,  33938 / 34433
# validating,  33939 / 34433
# validating,  33940 / 34433
# validating,  33941 / 34433
# validating,  33942 / 34433
# validating,  33943 / 34433
# validating,  33944 / 34433
# validating,  33945 / 34433
# validating,  33946 / 34433
# validating,  33947 / 34433
# validating,  33948 / 34433
# validating,  33949 / 34433
# validating,  33950 / 34433
# validating,  33951 / 34433
# validating,  33952 / 34433
# validating,  33953 / 34433
# validating,  33954 / 34433
# validating,  33955 / 34433
# validating,  33956 / 34433
# validating,  33957 / 34433
# validating,  33958 / 34433
# validating,  33959 / 34433
# validating,  33960 / 34433
# validating,  33961 / 34433
# validating,  33962 / 34433
# validating,  33963 / 34433
# validating,  33964 / 34433
# validating,  33965 / 34433
# validating,  33966 / 34433
# validating,  33967 / 34433
# validating,  33968 / 34433
# validating,  33969 / 34433
# validating,  33970 / 34433
# validating,  33971 / 34433
# validating,  33972 / 34433
# validating,  33973 / 34433
# validating,  33974 / 34433
# validating,  33975 / 34433
# validating,  33976 / 34433
# validating,  33977 / 34433
# validating,  33978 / 34433
# validating,  33979 / 34433
# validating,  33980 / 34433
# validating,  33981 / 34433
# validating,  33982 / 34433
# validating,  33983 / 34433
# validating,  33984 / 34433
# validating,  33985 / 34433
# validating,  33986 / 34433
# validating,  33987 / 34433
# validating,  33988 / 34433
# validating,  33989 / 34433
# validating,  33990 / 34433
# validating,  33991 / 34433
# validating,  33992 / 34433
# validating,  33993 / 34433
# validating,  33994 / 34433
# validating,  33995 / 34433
# validating,  33996 / 34433
# validating,  33997 / 34433
# validating,  33998 / 34433
# validating,  33999 / 34433
# validating,  34000 / 34433
# validating,  34001 / 34433
# validating,  34002 / 34433
# validating,  34003 / 34433
# validating,  34004 / 34433
# validating,  34005 / 34433
# validating,  34006 / 34433
# validating,  34007 / 34433
# validating,  34008 / 34433
# validating,  34009 / 34433
# validating,  34010 / 34433
# validating,  34011 / 34433
# validating,  34012 / 34433
# validating,  34013 / 34433
# validating,  34014 / 34433
# validating,  34015 / 34433
# validating,  34016 / 34433
# validating,  34017 / 34433
# validating,  34018 / 34433
# validating,  34019 / 34433
# validating,  34020 / 34433
# validating,  34021 / 34433
# validating,  34022 / 34433
# validating,  34023 / 34433
# validating,  34024 / 34433
# validating,  34025 / 34433
# validating,  34026 / 34433
# validating,  34027 / 34433
# validating,  34028 / 34433
# validating,  34029 / 34433
# validating,  34030 / 34433
# validating,  34031 / 34433
# validating,  34032 / 34433
# validating,  34033 / 34433
# validating,  34034 / 34433
# validating,  34035 / 34433
# validating,  34036 / 34433
# validating,  34037 / 34433
# validating,  34038 / 34433
# validating,  34039 / 34433
# validating,  34040 / 34433
# validating,  34041 / 34433
# validating,  34042 / 34433
# validating,  34043 / 34433
# validating,  34044 / 34433
# validating,  34045 / 34433
# validating,  34046 / 34433
# validating,  34047 / 34433
# validating,  34048 / 34433
# validating,  34049 / 34433
# validating,  34050 / 34433
# validating,  34051 / 34433
# validating,  34052 / 34433
# validating,  34053 / 34433
# validating,  34054 / 34433
# validating,  34055 / 34433
# validating,  34056 / 34433
# validating,  34057 / 34433
# validating,  34058 / 34433
# validating,  34059 / 34433
# validating,  34060 / 34433
# validating,  34061 / 34433
# validating,  34062 / 34433
# validating,  34063 / 34433
# validating,  34064 / 34433
# validating,  34065 / 34433
# validating,  34066 / 34433
# validating,  34067 / 34433
# validating,  34068 / 34433
# validating,  34069 / 34433
# validating,  34070 / 34433
# validating,  34071 / 34433
# validating,  34072 / 34433
# validating,  34073 / 34433
# validating,  34074 / 34433
# validating,  34075 / 34433
# validating,  34076 / 34433
# validating,  34077 / 34433
# validating,  34078 / 34433
# validating,  34079 / 34433
# validating,  34080 / 34433
# validating,  34081 / 34433
# validating,  34082 / 34433
# validating,  34083 / 34433
# validating,  34084 / 34433
# validating,  34085 / 34433
# validating,  34086 / 34433
# validating,  34087 / 34433
# validating,  34088 / 34433
# validating,  34089 / 34433
# validating,  34090 / 34433
# validating,  34091 / 34433
# validating,  34092 / 34433
# validating,  34093 / 34433
# validating,  34094 / 34433
# validating,  34095 / 34433
# validating,  34096 / 34433
# validating,  34097 / 34433
# validating,  34098 / 34433
# validating,  34099 / 34433
# validating,  34100 / 34433
# validating,  34101 / 34433
# validating,  34102 / 34433
# validating,  34103 / 34433
# validating,  34104 / 34433
# validating,  34105 / 34433
# validating,  34106 / 34433
# validating,  34107 / 34433
# validating,  34108 / 34433
# validating,  34109 / 34433
# validating,  34110 / 34433
# validating,  34111 / 34433
# validating,  34112 / 34433
# validating,  34113 / 34433
# validating,  34114 / 34433
# validating,  34115 / 34433
# validating,  34116 / 34433
# validating,  34117 / 34433
# validating,  34118 / 34433
# validating,  34119 / 34433
# validating,  34120 / 34433
# validating,  34121 / 34433
# validating,  34122 / 34433
# validating,  34123 / 34433
# validating,  34124 / 34433
# validating,  34125 / 34433
# validating,  34126 / 34433
# validating,  34127 / 34433
# validating,  34128 / 34433
# validating,  34129 / 34433
# validating,  34130 / 34433
# validating,  34131 / 34433
# validating,  34132 / 34433
# validating,  34133 / 34433
# validating,  34134 / 34433
# validating,  34135 / 34433
# validating,  34136 / 34433
# validating,  34137 / 34433
# validating,  34138 / 34433
# validating,  34139 / 34433
# validating,  34140 / 34433
# validating,  34141 / 34433
# validating,  34142 / 34433
# validating,  34143 / 34433
# validating,  34144 / 34433
# validating,  34145 / 34433
# validating,  34146 / 34433
# validating,  34147 / 34433
# validating,  34148 / 34433
# validating,  34149 / 34433
# validating,  34150 / 34433
# validating,  34151 / 34433
# validating,  34152 / 34433
# validating,  34153 / 34433
# validating,  34154 / 34433
# validating,  34155 / 34433
# validating,  34156 / 34433
# validating,  34157 / 34433
# validating,  34158 / 34433
# validating,  34159 / 34433
# validating,  34160 / 34433
# validating,  34161 / 34433
# validating,  34162 / 34433
# validating,  34163 / 34433
# validating,  34164 / 34433
# validating,  34165 / 34433
# validating,  34166 / 34433
# validating,  34167 / 34433
# validating,  34168 / 34433
# validating,  34169 / 34433
# validating,  34170 / 34433
# validating,  34171 / 34433
# validating,  34172 / 34433
# validating,  34173 / 34433
# validating,  34174 / 34433
# validating,  34175 / 34433
# validating,  34176 / 34433
# validating,  34177 / 34433
# validating,  34178 / 34433
# validating,  34179 / 34433
# validating,  34180 / 34433
# validating,  34181 / 34433
# validating,  34182 / 34433
# validating,  34183 / 34433
# validating,  34184 / 34433
# validating,  34185 / 34433
# validating,  34186 / 34433
# validating,  34187 / 34433
# validating,  34188 / 34433
# validating,  34189 / 34433
# validating,  34190 / 34433
# validating,  34191 / 34433
# validating,  34192 / 34433
# validating,  34193 / 34433
# validating,  34194 / 34433
# validating,  34195 / 34433
# validating,  34196 / 34433
# validating,  34197 / 34433
# validating,  34198 / 34433
# validating,  34199 / 34433
# validating,  34200 / 34433
# validating,  34201 / 34433
# validating,  34202 / 34433
# validating,  34203 / 34433
# validating,  34204 / 34433
# validating,  34205 / 34433
# validating,  34206 / 34433
# validating,  34207 / 34433
# validating,  34208 / 34433
# validating,  34209 / 34433
# validating,  34210 / 34433
# validating,  34211 / 34433
# validating,  34212 / 34433
# validating,  34213 / 34433
# validating,  34214 / 34433
# validating,  34215 / 34433
# validating,  34216 / 34433
# validating,  34217 / 34433
# validating,  34218 / 34433
# validating,  34219 / 34433
# validating,  34220 / 34433
# validating,  34221 / 34433
# validating,  34222 / 34433
# validating,  34223 / 34433
# validating,  34224 / 34433
# validating,  34225 / 34433
# validating,  34226 / 34433
# validating,  34227 / 34433
# validating,  34228 / 34433
# validating,  34229 / 34433
# validating,  34230 / 34433
# validating,  34231 / 34433
# validating,  34232 / 34433
# validating,  34233 / 34433
# validating,  34234 / 34433
# validating,  34235 / 34433
# validating,  34236 / 34433
# validating,  34237 / 34433
# validating,  34238 / 34433
# validating,  34239 / 34433
# validating,  34240 / 34433
# validating,  34241 / 34433
# validating,  34242 / 34433
# validating,  34243 / 34433
# validating,  34244 / 34433
# validating,  34245 / 34433
# validating,  34246 / 34433
# validating,  34247 / 34433
# validating,  34248 / 34433
# validating,  34249 / 34433
# validating,  34250 / 34433
# validating,  34251 / 34433
# validating,  34252 / 34433
# validating,  34253 / 34433
# validating,  34254 / 34433
# validating,  34255 / 34433
# validating,  34256 / 34433
# validating,  34257 / 34433
# validating,  34258 / 34433
# validating,  34259 / 34433
# validating,  34260 / 34433
# validating,  34261 / 34433
# validating,  34262 / 34433
# validating,  34263 / 34433
# validating,  34264 / 34433
# validating,  34265 / 34433
# validating,  34266 / 34433
# validating,  34267 / 34433
# validating,  34268 / 34433
# validating,  34269 / 34433
# validating,  34270 / 34433
# validating,  34271 / 34433
# validating,  34272 / 34433
# validating,  34273 / 34433
# validating,  34274 / 34433
# validating,  34275 / 34433
# validating,  34276 / 34433
# validating,  34277 / 34433
# validating,  34278 / 34433
# validating,  34279 / 34433
# validating,  34280 / 34433
# validating,  34281 / 34433
# validating,  34282 / 34433
# validating,  34283 / 34433
# validating,  34284 / 34433
# validating,  34285 / 34433
# validating,  34286 / 34433
# validating,  34287 / 34433
# validating,  34288 / 34433
# validating,  34289 / 34433
# validating,  34290 / 34433
# validating,  34291 / 34433
# validating,  34292 / 34433
# validating,  34293 / 34433
# validating,  34294 / 34433
# validating,  34295 / 34433
# validating,  34296 / 34433
# validating,  34297 / 34433
# validating,  34298 / 34433
# validating,  34299 / 34433
# validating,  34300 / 34433
# validating,  34301 / 34433
# validating,  34302 / 34433
# validating,  34303 / 34433
# validating,  34304 / 34433
# validating,  34305 / 34433
# validating,  34306 / 34433
# validating,  34307 / 34433
# validating,  34308 / 34433
# validating,  34309 / 34433
# validating,  34310 / 34433
# validating,  34311 / 34433
# validating,  34312 / 34433
# validating,  34313 / 34433
# validating,  34314 / 34433
# validating,  34315 / 34433
# validating,  34316 / 34433
# validating,  34317 / 34433
# validating,  34318 / 34433
# validating,  34319 / 34433
# validating,  34320 / 34433
# validating,  34321 / 34433
# validating,  34322 / 34433
# validating,  34323 / 34433
# validating,  34324 / 34433
# validating,  34325 / 34433
# validating,  34326 / 34433
# validating,  34327 / 34433
# validating,  34328 / 34433
# validating,  34329 / 34433
# validating,  34330 / 34433
# validating,  34331 / 34433
# validating,  34332 / 34433
# validating,  34333 / 34433
# validating,  34334 / 34433
# validating,  34335 / 34433
# validating,  34336 / 34433
# validating,  34337 / 34433
# validating,  34338 / 34433
# validating,  34339 / 34433
# validating,  34340 / 34433
# validating,  34341 / 34433
# validating,  34342 / 34433
# validating,  34343 / 34433
# validating,  34344 / 34433
# validating,  34345 / 34433
# validating,  34346 / 34433
# validating,  34347 / 34433
# validating,  34348 / 34433
# validating,  34349 / 34433
# validating,  34350 / 34433
# validating,  34351 / 34433
# validating,  34352 / 34433
# validating,  34353 / 34433
# validating,  34354 / 34433
# validating,  34355 / 34433
# validating,  34356 / 34433
# validating,  34357 / 34433
# validating,  34358 / 34433
# validating,  34359 / 34433
# validating,  34360 / 34433
# validating,  34361 / 34433
# validating,  34362 / 34433
# validating,  34363 / 34433
# validating,  34364 / 34433
# validating,  34365 / 34433
# validating,  34366 / 34433
# validating,  34367 / 34433
# validating,  34368 / 34433
# validating,  34369 / 34433
# validating,  34370 / 34433
# validating,  34371 / 34433
# validating,  34372 / 34433
# validating,  34373 / 34433
# validating,  34374 / 34433
# validating,  34375 / 34433
# validating,  34376 / 34433
# validating,  34377 / 34433
# validating,  34378 / 34433
# validating,  34379 / 34433
# validating,  34380 / 34433
# validating,  34381 / 34433
# validating,  34382 / 34433
# validating,  34383 / 34433
# validating,  34384 / 34433
# validating,  34385 / 34433
# validating,  34386 / 34433
# validating,  34387 / 34433
# validating,  34388 / 34433
# validating,  34389 / 34433
# validating,  34390 / 34433
# validating,  34391 / 34433
# validating,  34392 / 34433
# validating,  34393 / 34433
# validating,  34394 / 34433
# validating,  34395 / 34433
# validating,  34396 / 34433
# validating,  34397 / 34433
# validating,  34398 / 34433
# validating,  34399 / 34433
# validating,  34400 / 34433
# validating,  34401 / 34433
# validating,  34402 / 34433
# validating,  34403 / 34433
# validating,  34404 / 34433
# validating,  34405 / 34433
# validating,  34406 / 34433
# validating,  34407 / 34433
# validating,  34408 / 34433
# validating,  34409 / 34433
# validating,  34410 / 34433
# validating,  34411 / 34433
# validating,  34412 / 34433
# validating,  34413 / 34433
# validating,  34414 / 34433
# validating,  34415 / 34433
# validating,  34416 / 34433
# validating,  34417 / 34433
# validating,  34418 / 34433
# validating,  34419 / 34433
# validating,  34420 / 34433
# validating,  34421 / 34433
# validating,  34422 / 34433
# validating,  34423 / 34433
# validating,  34424 / 34433
# validating,  34425 / 34433
# validating,  34426 / 34433
# validating,  34427 / 34433
# validating,  34428 / 34433
# validating,  34429 / 34433
# validating,  34430 / 34433
# validating,  34431 / 34433
# validating,  34432 / 34433

# %%
# last: 48.2700 with 0.15 data, 1000 epoch
# best: 31.7282 with 0.15 data, 1200 epoch, batch_size = 512, austin
print(totalacc)
# Out:
# tensor(40.5954)

# %%
# save the trained model
# torch.save(model.state_dict(), "./model/" + city + "/trained_lstm" + "_lr%s_epoch%d_hd%d_%s_batch%d" % (str(learning_rate), epochs, hidden_dim, city, batch_size))
# np.save("./lossArr/" + "trained_lstm" + "_lr%s_epoch%d_hd%d_%s_batch%d" % (str(learning_rate), epochs, hidden_dim, city, batch_size), loss)
# load the trained model
model.load_state_dict(torch.load("./model/austin_trained_lstm_lr0.001_epoch1200_hd150_austin"))
# Out:
# <All keys matched successfully>

# %%
plt.plot(loss)
plt.title('Loss Graph')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.show()

# %%
# given velocity and starting point, generate path based on starting point chosen
#  generate output path (len = 60), or generate input path(len=50)
def genPath(pathVel, startP):
    path = [startP]
#         print(len(path_w_seed))
    for i in range(len(pathVel)):
        path.append(np.array(path[i]) + np.array(pathVel[i][:2]))
    return np.array(path[1:])


# validate the predicted path and actual path
# returns the validation loss (MSE loss)
def validate(model, city):
    model.eval()
    predLoss = nn.MSELoss()
    totalacc = 0
    mseArr = []
#     get validate data & startPoints
    inpVal, oupVal = getVelData(city, 'val')
    inpStartVal, oupStartVal = getStart(city, 'val')
    
#     get true paths
    inpTruePath, oupTruePath = get_city_trajectories(city, 'val')
    
#     predict with velocityArr
    for i, velPath in enumerate(inpVal):
        res = model.predict(torch.Tensor(velPath).to(device), 60)
        predPath = genPath(res, oupStartVal[i])
        truePath = oupTruePath[i]
        acc = predLoss(torch.Tensor(predPath), torch.Tensor(truePath))
        totalacc += acc
        mseArr.append(acc)
        print("validating, ", i, "/", len(inpVal))
#     calculate average MSE loss
    totalacc /= len(inpVal)
    return totalacc, mseArr
    
# master trainer that auto processes data for corresponding city, trains and saves the loss array & model
# returns the model trained
def trainNSave(city, learning_rate, epochs, input_dim, hidden_dim, layer_count, output_dim, batch_size, target_len, training_prediction='mixed_teacher_forcing', teacher_forcing_ratio=0.6):
    
#     data processing for training
    inputs, outputs = getVelData(city, 'train')
    in_tensor = torch.swapaxes(torch.Tensor(inputs),0,1).to(device)
    out_tensor = torch.swapaxes(torch.Tensor(outputs),0,1).to(device)
    
#     train the model
    model = lstm_seq2seq(input_size = input_dim, hidden_size = hidden_dim).to(device)
    model.train()
    loss = model.train_model(in_tensor, out_tensor, n_epochs = epochs, target_len = target_len, batch_size = batch_size, training_prediction = training_prediction, teacher_forcing_ratio = teacher_forcing_ratio, learning_rate = learning_rate, dynamic_tf = False)

#     save trained model & lossArr
    torch.save(model.state_dict(), "./model/" + city + "_trained_lstm" + "_lr%s_epoch%d_hd%d_%s" % (str(learning_rate), epochs, hidden_dim, city))
    np.save("./lossArr/" + "trained_lstm" + "_lr%s_epoch%d_hd%d_%s" % (str(learning_rate), epochs, hidden_dim, city), loss)
    
    plt.plot(loss)
    plt.title('Loss Graph')
    plt.xlabel('epoch')
    plt.ylabel('Loss')
    plt.show()
    
    return model

# %%
#     takes in the original data array
#     returns the velocity array as inputVel(x,y), starting from the 2nd step
def calcTestVel(dataArr):
    dataWV = []
    for path in np.array(dataArr):
        pathWV = []
#         get rid of the initial velocity
#         pathWV.append(path[1] - path[0])
        for coord in range(1, len(path)):
            changePos = path[coord] - path[coord-1]
#             Code for only velocity
            vel = path[coord] - path[coord-1]
            pathWV.append(vel)

#             Position change with actual velocity
#             posWithVel = np.concatenate((changePos, changePos*10))
#             pathWV.append(posWithVel)
    
        dataWV.append(pathWV)
    inp = []
    for path in dataWV:
        inp.append(path)
    return np.array(inp)

def getTestStart(city):
    
#     get test input, here oup = None
    inp, oup = get_city_trajectories(city, 'test')
    oupS= []
    for path in inp:
        oupS.append(path[49])
    return oupS

# give the model with dat for prediction, appends the data to csv
def test(model, city):
#     path to return, with predicted results
    outPaths = []
    
    model.eval()
#     get test input data, here output = none
    inp, oup = get_city_trajectories(city, 'test')
    oupStartVal = getTestStart(city)
#     get input velocity array
    inpVel = calcTestVel(inp)
    print(inpVel.shape)
    
#     predict with velocityArr
    for i, velPath in enumerate(inpVel):
        res = model.predict(torch.Tensor(velPath).to(device), 60)
        predPath = genPath(res, oupStartVal[i])
        if (i % 500 == 0 and i >= 500):
            print("predicting for ", city, ": ", i, "/", len(inpVel))
#         append the array to path
        outPaths.append(predPath)

    return outPaths

# %%
# Import writer class from csv module
import csv   

def getValStart(city):
    
#     get test input, here oup = None
    inp, oup = get_city_trajectories(city, 'val')
    oupS= []
    for path in inp:
        oupS.append(path[49])
    return oupS


# generates an array for all the predictions & write to csv
def genTest(model):
    
    for cityT in cities:
        model.load_state_dict(torch.load("./model/" + cityT + "_trained_lstm_lr0.0005_epoch1200_hd512_" + cityT))
#         model's prediction for the city
        out = test(model, cityT)
#     change the format into x,y,x,y,x,y
        flatOut = []
        for path in out:
            flatOut.append(np.array(path).flatten())
        
#         write to file
        with open('pred.csv', 'a+', newline='') as f:
            print("writing to file for city: ", cityT)
            writer = csv.writer(f)
            writer.writerows(flatOut)

            
# generates an validation array for all the cities
# returns two arrays, first is mse for each city, second is the detailed MSELoss Arr
def genValidation(model):
    accArr = []
    mseTotal = []
    
    for cityT in cities:
        model.load_state_dict(torch.load("./model/" + cityT + "_trained_lstm_lr0.0005_epoch1200_hd512_" + cityT))
#         model's prediction for the city
        acc, mseArr = validate(model, cityT)
        accArr.append(acc)
        mseTotal.append(mseArr)
    return accArr, mseTotal
            
# resacc, errArr = validate(model, 'austin')

# %%
abc = [[1,2],[2,3]]
abc = np.array(abc).flatten()
print(abc)
# Out:
# [1 2 2 3]

# %%
accArr, mseTotal = genValidation(model)
# Out:
# validating,  0 / 34433
# validating,  1 / 34433
# validating,  2 / 34433
# validating,  3 / 34433
# validating,  4 / 34433
# validating,  5 / 34433
# validating,  6 / 34433
# validating,  7 / 34433
# validating,  8 / 34433
# validating,  9 / 34433
# validating,  10 / 34433
# validating,  11 / 34433
# validating,  12 / 34433
# validating,  13 / 34433
# validating,  14 / 34433
# validating,  15 / 34433
# validating,  16 / 34433
# validating,  17 / 34433
# validating,  18 / 34433
# validating,  19 / 34433
# validating,  20 / 34433
# validating,  21 / 34433
# validating,  22 / 34433
# validating,  23 / 34433
# validating,  24 / 34433
# validating,  25 / 34433
# validating,  26 / 34433
# validating,  27 / 34433
# validating,  28 / 34433
# validating,  29 / 34433
# validating,  30 / 34433
# validating,  31 / 34433
# validating,  32 / 34433
# validating,  33 / 34433
# validating,  34 / 34433
# validating,  35 / 34433
# validating,  36 / 34433
# validating,  37 / 34433
# validating,  38 / 34433
# validating,  39 / 34433
# validating,  40 / 34433
# validating,  41 / 34433
# validating,  42 / 34433
# validating,  43 / 34433
# validating,  44 / 34433
# validating,  45 / 34433
# validating,  46 / 34433
# validating,  47 / 34433
# validating,  48 / 34433
# validating,  49 / 34433
# validating,  50 / 34433
# validating,  51 / 34433
# validating,  52 / 34433
# validating,  53 / 34433
# validating,  54 / 34433
# validating,  55 / 34433
# validating,  56 / 34433
# validating,  57 / 34433
# validating,  58 / 34433
# validating,  59 / 34433
# validating,  60 / 34433
# validating,  61 / 34433
# validating,  62 / 34433
# validating,  63 / 34433
# validating,  64 / 34433
# validating,  65 / 34433
# validating,  66 / 34433
# validating,  67 / 34433
# validating,  68 / 34433
# validating,  69 / 34433
# validating,  70 / 34433
# validating,  71 / 34433
# validating,  72 / 34433
# validating,  73 / 34433
# validating,  74 / 34433
# validating,  75 / 34433
# validating,  76 / 34433
# validating,  77 / 34433
# validating,  78 / 34433
# validating,  79 / 34433
# validating,  80 / 34433
# validating,  81 / 34433
# validating,  82 / 34433
# validating,  83 / 34433
# validating,  84 / 34433
# validating,  85 / 34433
# validating,  86 / 34433
# validating,  87 / 34433
# validating,  88 / 34433
# validating,  89 / 34433
# validating,  90 / 34433
# validating,  91 / 34433
# validating,  92 / 34433
# validating,  93 / 34433
# validating,  94 / 34433
# validating,  95 / 34433
# validating,  96 / 34433
# validating,  97 / 34433
# validating,  98 / 34433
# validating,  99 / 34433
# validating,  100 / 34433
# validating,  101 / 34433
# validating,  102 / 34433
# validating,  103 / 34433
# validating,  104 / 34433
# validating,  105 / 34433
# validating,  106 / 34433
# validating,  107 / 34433
# validating,  108 / 34433
# validating,  109 / 34433
# validating,  110 / 34433
# validating,  111 / 34433
# validating,  112 / 34433
# validating,  113 / 34433
# validating,  114 / 34433
# validating,  115 / 34433
# validating,  116 / 34433
# validating,  117 / 34433
# validating,  118 / 34433
# validating,  119 / 34433
# validating,  120 / 34433
# validating,  121 / 34433
# validating,  122 / 34433
# validating,  123 / 34433
# validating,  124 / 34433
# validating,  125 / 34433
# validating,  126 / 34433
# validating,  127 / 34433
# validating,  128 / 34433
# validating,  129 / 34433
# validating,  130 / 34433
# validating,  131 / 34433
# validating,  132 / 34433
# validating,  133 / 34433
# validating,  134 / 34433
# validating,  135 / 34433
# validating,  136 / 34433
# validating,  137 / 34433
# validating,  138 / 34433
# validating,  139 / 34433
# validating,  140 / 34433
# validating,  141 / 34433
# validating,  142 / 34433
# validating,  143 / 34433
# validating,  144 / 34433
# validating,  145 / 34433
# validating,  146 / 34433
# validating,  147 / 34433
# validating,  148 / 34433
# validating,  149 / 34433
# validating,  150 / 34433
# validating,  151 / 34433
# validating,  152 / 34433
# validating,  153 / 34433
# validating,  154 / 34433
# validating,  155 / 34433
# validating,  156 / 34433
# validating,  157 / 34433
# validating,  158 / 34433
# validating,  159 / 34433
# validating,  160 / 34433
# validating,  161 / 34433
# validating,  162 / 34433
# validating,  163 / 34433
# validating,  164 / 34433
# validating,  165 / 34433
# validating,  166 / 34433
# validating,  167 / 34433
# validating,  168 / 34433
# validating,  169 / 34433
# validating,  170 / 34433
# validating,  171 / 34433
# validating,  172 / 34433
# validating,  173 / 34433
# validating,  174 / 34433
# validating,  175 / 34433
# validating,  176 / 34433
# validating,  177 / 34433
# validating,  178 / 34433
# validating,  179 / 34433
# validating,  180 / 34433
# validating,  181 / 34433
# validating,  182 / 34433
# validating,  183 / 34433
# validating,  184 / 34433
# validating,  185 / 34433
# validating,  186 / 34433
# validating,  187 / 34433
# validating,  188 / 34433
# validating,  189 / 34433
# validating,  190 / 34433
# validating,  191 / 34433
# validating,  192 / 34433
# validating,  193 / 34433
# validating,  194 / 34433
# validating,  195 / 34433
# validating,  196 / 34433
# validating,  197 / 34433
# validating,  198 / 34433
# validating,  199 / 34433
# validating,  200 / 34433
# validating,  201 / 34433
# validating,  202 / 34433
# validating,  203 / 34433
# validating,  204 / 34433
# validating,  205 / 34433
# validating,  206 / 34433
# validating,  207 / 34433
# validating,  208 / 34433
# validating,  209 / 34433
# validating,  210 / 34433
# validating,  211 / 34433
# validating,  212 / 34433
# validating,  213 / 34433
# validating,  214 / 34433
# validating,  215 / 34433
# validating,  216 / 34433
# validating,  217 / 34433
# validating,  218 / 34433
# validating,  219 / 34433
# validating,  220 / 34433
# validating,  221 / 34433
# validating,  222 / 34433
# validating,  223 / 34433
# validating,  224 / 34433
# validating,  225 / 34433
# validating,  226 / 34433
# validating,  227 / 34433
# validating,  228 / 34433
# validating,  229 / 34433
# validating,  230 / 34433
# validating,  231 / 34433
# validating,  232 / 34433
# validating,  233 / 34433
# validating,  234 / 34433
# validating,  235 / 34433
# validating,  236 / 34433
# validating,  237 / 34433
# validating,  238 / 34433
# validating,  239 / 34433
# validating,  240 / 34433
# validating,  241 / 34433
# validating,  242 / 34433
# validating,  243 / 34433
# validating,  244 / 34433
# validating,  245 / 34433
# validating,  246 / 34433
# validating,  247 / 34433
# validating,  248 / 34433
# validating,  249 / 34433
# validating,  250 / 34433
# validating,  251 / 34433
# validating,  252 / 34433
# validating,  253 / 34433
# validating,  254 / 34433
# validating,  255 / 34433
# validating,  256 / 34433
# validating,  257 / 34433
# validating,  258 / 34433
# validating,  259 / 34433
# validating,  260 / 34433
# validating,  261 / 34433
# validating,  262 / 34433
# validating,  263 / 34433
# validating,  264 / 34433
# validating,  265 / 34433
# validating,  266 / 34433
# validating,  267 / 34433
# validating,  268 / 34433
# validating,  269 / 34433
# validating,  270 / 34433
# validating,  271 / 34433
# validating,  272 / 34433
# validating,  273 / 34433
# validating,  274 / 34433
# validating,  275 / 34433

# %%
print(accArr)
# Out:
# [tensor(37.6020), tensor(33.1207), tensor(34.8601), tensor(46.3723), tensor(37.6634), tensor(40.8871)]

# %%
genTest(model)
# Out:
# (6325, 49, 2)
# predicting for  austin :  500 / 6325
# predicting for  austin :  1000 / 6325
# predicting for  austin :  1500 / 6325
# predicting for  austin :  2000 / 6325
# predicting for  austin :  2500 / 6325
# predicting for  austin :  3000 / 6325
# predicting for  austin :  3500 / 6325
# predicting for  austin :  4000 / 6325
# predicting for  austin :  4500 / 6325
# predicting for  austin :  5000 / 6325
# predicting for  austin :  5500 / 6325
# predicting for  austin :  6000 / 6325
# writing to file for city:  austin
# (7971, 49, 2)
# predicting for  miami :  500 / 7971
# predicting for  miami :  1000 / 7971
# predicting for  miami :  1500 / 7971
# predicting for  miami :  2000 / 7971
# predicting for  miami :  2500 / 7971
# predicting for  miami :  3000 / 7971
# predicting for  miami :  3500 / 7971
# predicting for  miami :  4000 / 7971
# predicting for  miami :  4500 / 7971
# predicting for  miami :  5000 / 7971
# predicting for  miami :  5500 / 7971
# predicting for  miami :  6000 / 7971
# predicting for  miami :  6500 / 7971
# predicting for  miami :  7000 / 7971
# predicting for  miami :  7500 / 7971
# writing to file for city:  miami
# (6361, 49, 2)
# predicting for  pittsburgh :  500 / 6361
# predicting for  pittsburgh :  1000 / 6361
# predicting for  pittsburgh :  1500 / 6361
# predicting for  pittsburgh :  2000 / 6361
# predicting for  pittsburgh :  2500 / 6361
# predicting for  pittsburgh :  3000 / 6361
# predicting for  pittsburgh :  3500 / 6361
# predicting for  pittsburgh :  4000 / 6361
# predicting for  pittsburgh :  4500 / 6361
# predicting for  pittsburgh :  5000 / 6361
# predicting for  pittsburgh :  5500 / 6361
# predicting for  pittsburgh :  6000 / 6361
# writing to file for city:  pittsburgh
# (3671, 49, 2)
# predicting for  dearborn :  500 / 3671
# predicting for  dearborn :  1000 / 3671
# predicting for  dearborn :  1500 / 3671
# predicting for  dearborn :  2000 / 3671
# predicting for  dearborn :  2500 / 3671
# predicting for  dearborn :  3000 / 3671
# predicting for  dearborn :  3500 / 3671
# writing to file for city:  dearborn
# (3829, 49, 2)
# predicting for  washington-dc :  500 / 3829
# predicting for  washington-dc :  1000 / 3829
# predicting for  washington-dc :  1500 / 3829
# predicting for  washington-dc :  2000 / 3829
# predicting for  washington-dc :  2500 / 3829
# predicting for  washington-dc :  3000 / 3829
# predicting for  washington-dc :  3500 / 3829
# writing to file for city:  washington-dc
# (1686, 49, 2)
# predicting for  palo-alto :  500 / 1686
# predicting for  palo-alto :  1000 / 1686
# predicting for  palo-alto :  1500 / 1686
# writing to file for city:  palo-alto

# %%
for cityT in cities:
        model.load_state_dict(torch.load("./model/" + cityT + "_trained_lstm_lr0.001_epoch1200_hd150_" + cityT))
#         model's prediction for the city
        out = test(model, cityT)

# %%
# get each path's starting point & prediction starting point
def getStart(city, split):
        # get train data
    inp, oup = get_city_trajectories(city=city, split=split, normalized=False)
    # get whole path to calculate velocity
    togetherArr = []
    for i in range(len(inp)):
        togetherData = np.concatenate((inp[i], oup[i]))
        togetherArr.append(togetherData)
    inpS = []
    oupS = []
    for path in togetherArr:
        inpS.append(path[0])
        oupS.append(path[49])
    return inpS, oupS

inpStart, oupStart = getStart(city, split)

# %%
def showPath(path, color='r'):
    tempX = []
    tempY = []
    for elem in path:
        tempX.append(elem[0])
        tempY.append(elem[1])
    plt.scatter(tempX,tempY, c=color)

# %%
inpStartVal, oupStartVal = getStart(city, 'val')

# varName for Validation: inpVal, oupVal
# velocity array, begin symbol
res = model.predict(torch.Tensor(inpVal[120]).to(device), 60)
predPath = genPath(res, oupStartVal[120])
truePath = genPath(oupVal[120], oupStartVal[120])
pathStart = genPath(inpVal[120], inpStartVal[120])

print(predPath.shape)

predLoss = nn.MSELoss()
acc = predLoss(torch.Tensor(predPath), torch.Tensor(truePath))
print(acc)

showPath(predPath)
showPath(pathStart, 'b')
showPath(truePath, 'y')
# Out:
# (60, 2)
# tensor(187.9499)
